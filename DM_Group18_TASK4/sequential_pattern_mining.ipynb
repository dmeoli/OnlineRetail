# %% [markdown]
# # Task 4: Sequential Pattern Mining

# %%
import numpy as np
import pandas as pd
import copy

# %% [markdown]
# ## Loading the new dataset

# %%
df = pd.read_csv('../dataset/new_customer_supermarket.csv', sep='\t', index_col=0)
df
# Out:
#         BasketID           BasketDate  Sale  CustomerID ProdID  \
# 0         539993  2011-04-01 10:00:00  1.95     13313.0  22386
# 1         539993  2011-04-01 10:00:00  0.42     13313.0  21499
# 2         539993  2011-04-01 10:00:00  0.42     13313.0  21498
# 3         539993  2011-04-01 10:00:00  2.10     13313.0  22379
# 4         539993  2011-04-01 10:00:00  1.25     13313.0  20718
# ...          ...                  ...   ...         ...    ...
# 363572    581587  2011-09-12 12:50:00  0.85     12680.0  22613
# 363573    581587  2011-09-12 12:50:00  2.10     12680.0  22899
# 363574    581587  2011-09-12 12:50:00  4.15     12680.0  23254
# 363575    581587  2011-09-12 12:50:00  4.15     12680.0  23255
# 363576    581587  2011-09-12 12:50:00  4.95     12680.0  22138
#
#                               ProdDescr  Qta  TotSale
# 0               JUMBO BAG PINK POLKADOT   10    19.50
# 1                    BLUE POLKADOT WRAP   25    10.50
# 2                    RED RETROSPOT WRAP   25    10.50
# 3               RECYCLING BAG RETROSPOT    5    10.50
# 4             RED RETROSPOT SHOPPER BAG   10    12.50
# ...                                 ...  ...      ...
# 363572         PACK OF SPACEBOY NAPKINS   12    10.20
# 363573       CHILDRENS APRON DOLLY GIRL    6    12.60
# 363574     CHILDRENS CUTLERY DOLLY GIRL    4    16.60
# 363575  CHILDRENS CUTLERY CIRCUS PARADE    4    16.60
# 363576       BAKING SET PIECE RETROSPOT    3    14.85
#
# [363577 rows x 8 columns]

# %%
df.dtypes
# Out:
# BasketID        int64
# BasketDate     object
# Sale          float64
# CustomerID    float64
# ProdID         object
# ProdDescr      object
# Qta             int64
# TotSale       float64
# dtype: object

# %%
df = df.astype({'BasketDate': 'datetime64',
                'BasketID': 'object',
                'CustomerID': 'object'})

# %% [markdown]
# ## AprioriAll

# %%
dataset = [
    # sequence: list of events
    {1 : ['a'],  # event {timestamp : list of strings}
     2 : ['a', 'b', 'c'], 
     3 : ['a', 'c'], 
     4 : ['c']}, 
    {1 : ['a'], 
     3 : ['c'], 
     4 : ['b', 'c']}, 
    {1 : ['a', 'b'], 
     2 : ['d'], 
     4 : ['c'], 
     5 : ['b'], 
     6 : ['c']}, 
    {1 : ['a'], 
     2 : ['c'], 
     3 : ['b'], 
     4 : ['c']}
]

# %%
"""
Recursive method that checks if `subsequence` is a subsequence of `main_sequence`
"""
def is_subsequence(main_sequence, subsequence):
    
    """
    Function for the recursive call of is_subsequence
    """
    def is_subsequence_recursive(subsequence_clone, start=0):
        # check if empty: end of recursion, all itemsets have been found
        if not subsequence_clone:
            return True
        # retrieves element of the subsequence and removes is from subsequence 
        first_elem = set(subsequence_clone.pop(0))
        # search for the first itemset...
        for i in range(start, len(main_sequence)):
            if set(main_sequence[i]).issuperset(first_elem):
                # and recurse
                return is_subsequence_recursive(subsequence_clone, i + 1)
        return False

    return is_subsequence_recursive(subsequence.copy()) # start recursion

# %%
sequence = [['a'], ['b', 'c'], ['d'], ['a', 'e']]

# %%
is_subsequence(sequence, [['a'], ['b', 'c'], ['e']])
# Out:
# True

# %%
is_subsequence(sequence, [['a'], ['b', 'd']])
# Out:
# False

# %%
"""
Computes the length of the sequence (sum of the length of the contained itemsets)
"""
def sequence_length(sequence):
    return sum(len(i) for i in sequence)

# %%
sequence_length([['a'], ['b', 'c'], ['a'], ['b', 'c', 'd']])
# Out:
# 7

# %%
"""
Computes the support of a sequence in a dataset
"""
def count_support(dataset, cand_seq):
    return sum(1 for seq in dataset if is_subsequence(seq, cand_seq))

# %%
count_support(dataset, [['b']])
# Out:
# 4

# %%
count_support(dataset, [['a'], ['b', 'c']])
# Out:
# 2

# %%
"""
Generates one candidate of length k from two candidates of length (k-1)
"""
def gen_cands_for_pair(cand1, cand2):
    cand1_clone = copy.deepcopy(cand1)
    cand2_clone = copy.deepcopy(cand2)
    # drop the leftmost item from cand1:
    if len(cand1[0]) == 1:
        cand1_clone.pop(0)
    else:
        cand1_clone[0] = cand1_clone[0][1:]
    # drop the rightmost item from cand2:
    if len(cand2[-1]) == 1:
        cand2_clone.pop(-1)
    else:
        cand2_clone[-1] = cand2_clone[-1][:-1]
    
    # if the result is not the same, then we dont need to join
    if not cand1_clone == cand2_clone:
        return []
    else:
        new_cand = copy.deepcopy(cand1)
        if len(cand2[-1]) == 1:
            new_cand.append(cand2[-1])
        else:
            new_cand[-1].extend(cand2[-1][-1])
        return new_cand

# %%
candA = [['a'], ['b', 'c'], ['d']]
candB = [['b', 'c'], ['d', 'e']]
gen_cands_for_pair(candA, candB)
# Out:
# [['a'], ['b', 'c'], ['d', 'e']]

# %%
candA = [['a'], ['b', 'c'], ['d']]
candC = [['b', 'c'], ['d'], ['e']]
gen_cands_for_pair(candA, candC)
# Out:
# [['a'], ['b', 'c'], ['d'], ['e']]

# %%
candA = [['a'], ['b', 'c'], ['d']]
candD = [['a'], ['b', 'c'], ['e']]
gen_cands_for_pair(candA, candD)
# Out:
# []

# %%
"""
Generates the set of candidates of length k from the set of frequent sequences with length (k-1)
"""
def gen_cands(last_lvl_cands):
    k = sequence_length(last_lvl_cands[0]) + 1
    if k == 2:
        flat_short_cands = [item for sublist2 in last_lvl_cands for sublist1 in sublist2 for item in sublist1]
        result = [[[a, b]] for a in flat_short_cands for b in flat_short_cands if b > a]
        result.extend([[[a], [b]] for a in flat_short_cands for b in flat_short_cands])
        return result
    else:
        cands = []
        for i in range(0, len(last_lvl_cands)):
            for j in range(0, len(last_lvl_cands)):
                new_cand = gen_cands_for_pair(last_lvl_cands[i], last_lvl_cands[j])
                if not new_cand == []:
                    cands.append(new_cand)
        cands.sort()
        return cands

# %% [markdown]
# Lets assume we know the frequent sequences of level 2:

# %%
last_lvl_freq_patterns = [
    [['a', 'b']], 
    [['b', 'c']], 
    [['a'], ['b']], 
    [['a'], ['c']], 
    [['b'], ['c']], 
    [['c'], ['b']], 
    [['c'], ['c']]
]

# %% [markdown]
# Then we can compute the generate candidates for level 3:

# %%
new_cands = gen_cands(last_lvl_freq_patterns)
new_cands
# Out:
# [[['a'], ['b'], ['c']],
#  [['a'], ['b', 'c']],
#  [['a'], ['c'], ['b']],
#  [['a'], ['c'], ['c']],
#  [['a', 'b'], ['c']],
#  [['a', 'b', 'c']],
#  [['b'], ['c'], ['b']],
#  [['b'], ['c'], ['c']],
#  [['b', 'c'], ['b']],
#  [['b', 'c'], ['c']],
#  [['c'], ['b'], ['c']],
#  [['c'], ['b', 'c']],
#  [['c'], ['c'], ['b']],
#  [['c'], ['c'], ['c']]]

# %%
"""
Computes all direct subsequence for a given sequence.
A direct subsequence is any sequence that originates from deleting exactly one item from any event in the original sequence.
"""
def gen_direct_subsequences(sequence):
    result = []
    for i, itemset in enumerate(sequence):
        if len(itemset) == 1:
            seq_clone = copy.deepcopy(sequence)
            seq_clone.pop(i)
            result.append(seq_clone)
        else:
            for j in range(len(itemset)):
                seq_clone = copy.deepcopy(sequence)
                seq_clone[i].pop(j)
                result.append(seq_clone)
    return result

"""
Prunes the set of candidates generated for length k given all frequent sequence of level (k-1)
"""
def prune_cands(cands_last_lvl, cands_gen):
    return [cand for cand in cands_gen if all(x in cands_last_lvl for x in gen_direct_subsequences(cand))]

# %% [markdown]
# We apply this on example dataset:

# %%
cands_pruned = prune_cands(last_lvl_freq_patterns, new_cands)
cands_pruned
# Out:
# [[['a'], ['b'], ['c']],
#  [['a'], ['b', 'c']],
#  [['a'], ['c'], ['b']],
#  [['a'], ['c'], ['c']],
#  [['a', 'b'], ['c']],
#  [['b'], ['c'], ['c']],
#  [['b', 'c'], ['c']],
#  [['c'], ['b'], ['c']],
#  [['c'], ['b', 'c']],
#  [['c'], ['c'], ['b']],
#  [['c'], ['c'], ['c']]]

# %%
def check_cands(dataset, cands_pruned, min_sup):
    cands_counts = [(i, count_support(dataset, i)) for i in cands_pruned]
    return [(i, count) for i, count in cands_counts if count >= min_sup]

# %%
result_lvl = check_cands(dataset, cands_pruned, 2)
result_lvl
# Out:
# [([['a'], ['b'], ['c']], 3),
#  ([['a'], ['b', 'c']], 2),
#  ([['a'], ['c'], ['b']], 3),
#  ([['a'], ['c'], ['c']], 4),
#  ([['a', 'b'], ['c']], 2),
#  ([['b'], ['c'], ['c']], 2),
#  ([['c'], ['b'], ['c']], 2)]

# %%
"""
The AprioriAll algorithm with time constraints. Computes the frequent sequences in a seqeunce dataset.

Args:
    dataset: a list of sequences, for which the frequent (sub-)sequences are computed
    min_sup: the minimum support that makes a sequence frequent
    max_span: this constraint specifies the maximum allowed time difference in days between the latest 
              and the earliest occurrences of events in the entire sequence
    min_gap: this constraint specifies the minimum allowed time difference in days between the latest 
             and the earliest element of the pattern instance
    max_gap: this constraint specifies the maximum allowed time difference in days between the latest 
             and the earliest element of the pattern instance
    verbose: if True, additional informations on the mining process are printed (i.e., results 
             for each level if is True, candidates generated and pruned at each level otherwise)

Returns:
    A list of tuples (s, c), where s is a frequent sequence and c is the count for that sequence
"""
def aprioriall(dataset, min_sup, max_span=np.inf, min_gap=1, max_gap=np.inf, verbose=False):
    overall = []
    items = sorted(set([item for sublist1 in dataset for sublist2 in sublist1 for item in sublist2]))
    single_item_sequences = [[[item]] for item in items]
    single_item_counts = [(i, count_support(dataset, i)) for i in single_item_sequences 
                        if count_support(dataset, i) >= min_sup]
    overall.append(single_item_counts)
    if verbose > 0:
        print('Result, lvl 1: ' + str(overall[0]))
    k = 1
    while True:
        if not overall[k-1]:
            break
        # 1. candidate generation
        cands_last_lvl = [x[0] for x in overall[k-1]]
        cands_gen = gen_cands(cands_last_lvl)
        # 2. candidate pruning (using a "containsall" subsequences)
        cands_pruned = prune_cands(cands_last_lvl, cands_gen)
        # 3. candidate checking
        result_lvl = check_cands(dataset, cands_pruned, min_sup)
        if verbose > 0:
            print('Result, lvl ' + str(k+1) + ': ' + str(result_lvl))
            if verbose > 1:
                print('Candidates generated, lvl ' + str(k+1) + ': ' + str(cands_gen))
                print('Candidates pruned, lvl ' + str(k+1) + ': ' + str(cands_pruned))
        overall.append(result_lvl)
        k += 1
    # "flatten" overall
    overall = overall[:-1]
    overall = [item for sublist in overall for item in sublist]
    return overall

# %%
aprioriall(dataset, min_sup=2, verbose=2)
# Out:
# Result, lvl 1: [([['a']], 4), ([['b']], 4), ([['c']], 4)]
# Result, lvl 2: [([['a', 'b']], 2), ([['b', 'c']], 2), ([['a'], ['b']], 4), ([['a'], ['c']], 4), ([['b'], ['c']], 3), ([['c'], ['b']], 3), ([['c'], ['c']], 4)]
# Candidates generated, lvl 2: [[['a', 'b']], [['a', 'c']], [['b', 'c']], [['a'], ['a']], [['a'], ['b']], [['a'], ['c']], [['b'], ['a']], [['b'], ['b']], [['b'], ['c']], [['c'], ['a']], [['c'], ['b']], [['c'], ['c']]]
# Candidates pruned, lvl 2: [[['a', 'b']], [['a', 'c']], [['b', 'c']], [['a'], ['a']], [['a'], ['b']], [['a'], ['c']], [['b'], ['a']], [['b'], ['b']], [['b'], ['c']], [['c'], ['a']], [['c'], ['b']], [['c'], ['c']]]
# Result, lvl 3: [([['a'], ['b'], ['c']], 3), ([['a'], ['b', 'c']], 2), ([['a'], ['c'], ['b']], 3), ([['a'], ['c'], ['c']], 4), ([['a', 'b'], ['c']], 2), ([['b'], ['c'], ['c']], 2), ([['c'], ['b'], ['c']], 2)]
# Candidates generated, lvl 3: [[['a'], ['b'], ['c']], [['a'], ['b', 'c']], [['a'], ['c'], ['b']], [['a'], ['c'], ['c']], [['a', 'b'], ['c']], [['a', 'b', 'c']], [['b'], ['c'], ['b']], [['b'], ['c'], ['c']], [['b', 'c'], ['b']], [['b', 'c'], ['c']], [['c'], ['b'], ['c']], [['c'], ['b', 'c']], [['c'], ['c'], ['b']], [['c'], ['c'], ['c']]]
# Candidates pruned, lvl 3: [[['a'], ['b'], ['c']], [['a'], ['b', 'c']], [['a'], ['c'], ['b']], [['a'], ['c'], ['c']], [['a', 'b'], ['c']], [['b'], ['c'], ['c']], [['b', 'c'], ['c']], [['c'], ['b'], ['c']], [['c'], ['b', 'c']], [['c'], ['c'], ['b']], [['c'], ['c'], ['c']]]
# Result, lvl 4: [([['a'], ['c'], ['b'], ['c']], 2), ([['a', 'b'], ['c'], ['c']], 2)]
# Candidates generated, lvl 4: [[['a'], ['b'], ['c'], ['c']], [['a'], ['c'], ['b'], ['c']], [['a', 'b'], ['c'], ['c']], [['c'], ['b'], ['c'], ['c']]]
# Candidates pruned, lvl 4: [[['a'], ['b'], ['c'], ['c']], [['a'], ['c'], ['b'], ['c']], [['a', 'b'], ['c'], ['c']]]
# Result, lvl 5: []
# Candidates generated, lvl 5: []
# Candidates pruned, lvl 5: []
# [([['a']], 4),
#  ([['b']], 4),
#  ([['c']], 4),
#  ([['a', 'b']], 2),
#  ([['b', 'c']], 2),
#  ([['a'], ['b']], 4),
#  ([['a'], ['c']], 4),
#  ([['b'], ['c']], 3),
#  ([['c'], ['b']], 3),
#  ([['c'], ['c']], 4),
#  ([['a'], ['b'], ['c']], 3),
#  ([['a'], ['b', 'c']], 2),
#  ([['a'], ['c'], ['b']], 3),
#  ([['a'], ['c'], ['c']], 4),
#  ([['a', 'b'], ['c']], 2),
#  ([['b'], ['c'], ['c']], 2),
#  ([['c'], ['b'], ['c']], 2),
#  ([['a'], ['c'], ['b'], ['c']], 2),
#  ([['a', 'b'], ['c'], ['c']], 2)]

# %%
"""
Given a list of all frequent sequences and their counts, compute the set of closed frequent sequence
"""
def filter_closed(result):
    for supersequence, count_seq in copy.deepcopy(result):
        for subsequence, count_subseq in copy.deepcopy(result):
            if is_subsequence(supersequence, subsequence) and count_seq == count_subseq and subsequence != supersequence:
                result.remove((subsequence, count_subseq))

# %%
result = aprioriall(dataset, min_sup=2, verbose=False)
filter_closed(result)
result
# Out:
# [([['a'], ['b']], 4),
#  ([['a'], ['b'], ['c']], 3),
#  ([['a'], ['b', 'c']], 2),
#  ([['a'], ['c'], ['b']], 3),
#  ([['a'], ['c'], ['c']], 4),
#  ([['a'], ['c'], ['b'], ['c']], 2),
#  ([['a', 'b'], ['c'], ['c']], 2)]

# %%
"""
Given a list of all frequent sequences and their counts, compute the set of maximal frequent sequence
"""
def filter_maximal(result):
    for supersequence, count_seq in copy.deepcopy(result):
        for subsequence, count_subseq in copy.deepcopy(result):
            if is_subsequence(supersequence, subsequence) and subsequence != supersequence:
                result.remove((subsequence, count_subseq))

# %%
result = aprioriall(dataset, min_sup=2, verbose=False)
filter_maximal(result)
result
# Out:
# [([['a'], ['b', 'c']], 2),
#  ([['a'], ['c'], ['b'], ['c']], 2),
#  ([['a', 'b'], ['c'], ['c']], 2)]

# %% [markdown]
# ### Supermarket dataset

# %% [raw]
# dataset = [
#     # customer: sequence of baskets
#     {1 : ['item_x', 'item_y', 'item_z', etc.],  # basket {day of the year : list of products}
#      2 : ['item_p', 'item_q', 'item_r', etc.],
#      3 : [etc.]},
#     etc.
# ]

# %%
baskets_sequence = pd.DataFrame(df.sort_values('BasketDate').groupby(['CustomerID', 'BasketID', 'BasketDate'])['ProdDescr'].apply(list))
baskets_sequence
# Out:
#                                                                                  ProdDescr
# CustomerID BasketID BasketDate
# 12347.0    542237   2011-01-26 14:30:00  [PACK OF SPACEBOY CAKE CASES, TEA TIME OVEN GL...
#            549222   2011-07-04 10:43:00  [SET OF TINS VINTAGE BATHROOM, GIFT BAG PSYCHE...
#            556201   2011-09-06 13:01:00  [ALARM CLOCK BAKELIKE RED, FEATHER PENCOAL BLA...
#            562032   2011-02-08 08:48:00  [SWEETHEART FAIRY CAKE CASES, RED REFECTORY CL...
#            573511   2011-10-31 12:25:00  [ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...
# ...                                                                                    ...
# 18283.0    579673   2011-11-30 12:59:00  [LUNCH BAG DOLLY GIRL DESIGN, LUNCH BAG SUKI D...
#            580872   2011-06-12 12:02:00  [STRAWBERRY SHOPPER BAG, RED RETROSPOT SHOPPER...
# 18287.0    554065   2011-05-22 10:39:00  [SET SPRING FLOWER DECORATION, CERAMIC CHERRY ...
#            570715   2011-12-10 10:23:00  [SET FROG PRINCE TLIGHT CANDLES, ASSORTED MONK...
#            573167   2011-10-28 09:29:00  [SWISS CHALET TREE DECORATION, SET OF WOODEN S...
#
# [16950 rows x 1 columns]

# %%
baskets_sequence = pd.DataFrame(baskets_sequence.sort_values('BasketDate').groupby('CustomerID')['ProdDescr'].apply(list))
baskets_sequence
# Out:
#                                                     ProdDescr
# CustomerID
# 12347.0     [[PACK OF SPACEBOY CAKE CASES, TEA TIME OVEN G...
# 12348.0     [[PACK OF SKULL TISSUES, MULTI HEARTS STICKERS...
# 12349.0     [[PANTRY CHOPPING BOARD, SMALL WHITE RETROSPOT...
# 12350.0     [[BLUE POLKADOT PASSPORT COVER, RED HARMONICA ...
# 12352.0     [[DELUXE SEWING KIT, PINK HEART SHAPE EGG FRYI...
# ...                                                       ...
# 18280.0     [[SET OF ROUND TINS CAMEMBERT, KINGS CHOICE TE...
# 18281.0     [[ROBOT BIRTHDAY CARD, CARD CIRCUS PARADE, PEN...
# 18282.0     [[REGENCY SUGAR BOWL GREEN, CARD CHRISTMAS VIL...
# 18283.0     [[BLUE PIECE POLKADOT CUTLERY SET, TEA TIME OV...
# 18287.0     [[SET SPRING FLOWER DECORATION, CERAMIC CHERRY...
#
# [4206 rows x 1 columns]

# %%
baskets_sequence = baskets_sequence['ProdDescr'].tolist()
baskets_sequence[:1]
# Out:
# [[['PACK OF SPACEBOY CAKE CASES',
#    'TEA TIME OVEN GLOVE',
#    'RED RETROSPOT OVEN GLOVE',
#    'RED RETROSPOT OVEN GLOVE DOUBLE',
#    'SET RED RETROSPOT TEA TOWELS',
#    'REGENCY CAKESTAND TIER',
#    'TOOTHPASTE TUBE PEN',
#    'MINI LADLE LOVE HEART RED',
#    'CHOCOLATE CALCULATOR',
#    'SET OF TINS VINTAGE BATHROOM',
#    'RED TOADSTOOL LED NIGHT LIGHT',
#    'DOG PICTURE PLAYING CARDS',
#    'BOX OF ASSORTED COLOUR TEASPOONS',
#    'TEATIME FAIRY CAKE CASES',
#    'PACK OF MUSHROOM CAKE CASES',
#    'SMALL HEART MEASURING SPOONS',
#    'SWEETHEART FAIRY CAKE CASES',
#    'BLUE NEW BAROQUE CANDLESTICK CANDLE',
#    'BLACK CANDELABRA TLIGHT HOLDER',
#    'WOODLAND CHARLOTTE BAG',
#    'AIRLINE BAG VINTAGE JET SET BROWN',
#    'AIRLINE BAG VINTAGE JET SET WHITE',
#    'PINK NEW BAROQUECANDLESTICK CANDLE',
#    'ALARM CLOCK BAKELIKE CHOCOLATE',
#    'ALARM CLOCK BAKELIKE GREEN',
#    'ALARM CLOCK BAKELIKE RED',
#    'ALARM CLOCK BAKELIKE PINK',
#    'ALARM CLOCK BAKELIKE ORANGE',
#    'SANDWICH BATH SPONGE'],
#   ['SWEETHEART FAIRY CAKE CASES',
#    'RED REFECTORY CLOCK',
#    'VINTAGE HEADS AND TAILS CARD GAME',
#    'DOG PICTURE PLAYING CARDS',
#    'REGENCY MILK JUG PINK',
#    'REGENCY CAKESTAND TIER',
#    'PACK OF DINOSAUR CAKE CASES',
#    'TEATIME FAIRY CAKE CASES',
#    'TEA TIME OVEN GLOVE',
#    'REVOLVER WOODEN RULER',
#    'TRIPLE HOOK ANTIQUE IVORY ROSE',
#    'SET HEART SHAPE PETIT FOUR CASES',
#    'AIRLINE BAG VINTAGE JET SET BROWN',
#    'SINGLE ANTIQUE ROSE HOOK IVORY',
#    'SET OF VINTAGE LEAF CAKE CASES',
#    'AIRLINE BAG VINTAGE JET SET WHITE',
#    'AIRLINE BAG VINTAGE JET SET RED',
#    'AIRLINE BAG VINTAGE WORLD CHAMPION',
#    'WOODLAND DESIGN COTTON TOTE BAG',
#    'WOODLAND CHARLOTTE BAG',
#    'ALARM CLOCK BAKELIKE RED',
#    'AIRLINE BAG VINTAGE TOKYO'],
#   ['SET OF TINS VINTAGE BATHROOM',
#    'GIFT BAG PSYCHEDELIC APPLES',
#    'SMALL FOLDING SCISSORPOINTED EDGE',
#    'SHEET OF CAT STICKERS',
#    'SHEET OF DOG STICKERS',
#    'RED TOADSTOOL LED NIGHT LIGHT',
#    'ROSES REGENCY TEACUP AND SAUCER',
#    'REGENCY CAKESTAND TIER',
#    'RED RETROSPOT OVEN GLOVE DOUBLE',
#    'PACK OF DINOSAUR CAKE CASES',
#    'LARGE HEART MEASURING SPOONS',
#    'RED DRAWER KNOB ACRYLIC EDWARDIAN',
#    'WATERING CAN PINK BUNNY',
#    'TREASURE ISLAND BOOK BOX',
#    'HOLIDAY FUN LUDO',
#    'VINTAGE HEADS AND TAILS CARD GAME',
#    'RED RETROSPOT PURSE',
#    'AIRLINE BAG VINTAGE JET SET BROWN',
#    'AIRLINE BAG VINTAGE TOKYO',
#    'AIRLINE BAG VINTAGE JET SET RED',
#    'AIRLINE BAG VINTAGE JET SET WHITE',
#    'SMALL HEART MEASURING SPOONS',
#    'ICE CREAM SUNDAE LIP GLOSS',
#    'MINI PAINT SET VINTAGE'],
#   ['PINK GOOSE FEATHER TREE',
#    'MINI PLAYING CARDS DOLLY GIRL',
#    'MINI PLAYING CARDS SPACEBOY',
#    'CHRISTMAS TABLE SILVER CANDLE SPIKE',
#    'WOODLAND CHARLOTTE BAG',
#    'CLASSIC CHROME BICYCLE BELL',
#    'RED TOADSTOOL LED NIGHT LIGHT',
#    'PINK NEW BAROQUECANDLESTICK CANDLE',
#    'BOOM BOX SPEAKER BOYS',
#    'BICYCLE PUNCTURE REPAIR KIT',
#    'RABBIT NIGHT LIGHT'],
#   ['ALARM CLOCK BAKELIKE RED',
#    'FEATHER PENCOAL BLACK',
#    'DOG PICTURE PLAYING CARDS',
#    'SMALL HEART MEASURING SPOONS',
#    'TRIPLE HOOK ANTIQUE IVORY ROSE',
#    'ALARM CLOCK BAKELIKE CHOCOLATE',
#    'NAMASTE SWAGAT INCENSE',
#    'VICTORIAN SEWING KIT',
#    'AIRLINE BAG VINTAGE JET SET BROWN',
#    'REGENCY TEA PLATE ROSES',
#    'REGENCY MILK JUG PINK',
#    'REGENCY SUGAR BOWL GREEN',
#    'REGENCY TEAPOT ROSES',
#    'REGENCY TEA PLATE PINK',
#    'REGENCY TEA PLATE GREEN',
#    'REGENCY TEA STRAINER',
#    'RABBIT NIGHT LIGHT',
#    'AIRLINE BAG VINTAGE TOKYO'],
#   ['ALARM CLOCK BAKELIKE GREEN',
#    'ALARM CLOCK BAKELIKE RED',
#    'PACK OF MUSHROOM CAKE CASES',
#    'PACK OF SPACEBOY CAKE CASES',
#    'SET OF VINTAGE LEAF CAKE CASES',
#    'LARGE HEART MEASURING SPOONS',
#    'SWEETHEART FAIRY CAKE CASES',
#    'SMALL HEART MEASURING SPOONS',
#    'WOODLAND CHARLOTTE BAG',
#    'FOOD CONTAINER SET LOVE HEART',
#    'ALARM CLOCK BAKELIKE PINK',
#    'TEATIME FAIRY CAKE CASES',
#    'ALARM CLOCK BAKELIKE CHOCOLATE',
#    'REGENCY TEA STRAINER',
#    'PANTRY HOOK TEA STRAINER',
#    'DOG PICTURE PLAYING CARDS',
#    'GREEN REGENCY TEACUP AND SAUCER',
#    'PINK REGENCY TEACUP AND SAUCER',
#    'TEA TIME OVEN GLOVE',
#    'TEA TIME KITCHEN APRON',
#    'TEA TIME DES TEA COSY',
#    'REGENCY TEAPOT ROSES',
#    'REGENCY CAKESTAND TIER',
#    'CHRISTMAS METAL TAGS ASSORTED',
#    'BIRDCAGE DECORATION TEALIGHT HOLDER',
#    'AIRLINE BAG VINTAGE JET SET RED',
#    'AIRLINE BAG VINTAGE TOKYO',
#    'AIRLINE BAG VINTAGE JET SET BROWN',
#    'AIRLINE BAG VINTAGE WORLD CHAMPION',
#    'MADRAS NOTEBOOK MEDIUM',
#    'PINK GOOSE FEATHER TREE',
#    'MINI LIGHTS WOODLAND MUSHROOMS',
#    'RED TOADSTOOL LED NIGHT LIGHT',
#    'ROSES REGENCY TEACUP AND SAUCER',
#    'RABBIT NIGHT LIGHT',
#    'MINI PLAYING CARDS DOLLY GIRL',
#    'WOODEN SCHOOL COLOURING SET',
#    'MINI PLAYING CARDS SPACEBOY',
#    'MINI PAINT SET VINTAGE',
#    'TRADITIONAL KNITTING NANCY',
#    'TRIPLE HOOK ANTIQUE IVORY ROSE',
#    'PANTRY HOOK SPATULA',
#    'PANTRY HOOK BALLOON WHISK',
#    'REVOLVER WOODEN RULER',
#    'PLAYING CARDS KEEP CALM CARRY ON',
#    'TREASURE ISLAND BOOK BOX',
#    'VINTAGE HEADS AND TAILS CARD GAME']]]

# %%
result = aprioriall(baskets_sequence, min_sup=150, verbose=False)
filter_closed(result)
result
# Out:
# [([['ABC TREASURE BOOK BOX']], 157),
#  ([['ALARM CLOCK BAKELIKE CHOCOLATE']], 163),
#  ([['ALARM CLOCK BAKELIKE GREEN']], 305),
#  ([['ALARM CLOCK BAKELIKE IVORY']], 232),
#  ([['ALARM CLOCK BAKELIKE ORANGE']], 166),
#  ([['ALARM CLOCK BAKELIKE PINK']], 277),
#  ([['ALARM CLOCK BAKELIKE RED']], 372),
#  ([['ANTIQUE SILVER TEA GLASS ENGRAVED']], 162),
#  ([['ANTIQUE SILVER TLIGHT GLASS']], 346),
#  ([['AREA PATROLLED METAL SIGN']], 172),
#  ([['ASSORTED COLOUR BIRD ORNAMENT']], 651),
#  ([['ASSORTED COLOUR MINI CASES']], 223),
#  ([['ASSORTED COLOURS SILK FAN']], 187),
#  ([['BAG SWIRLY MARBLES']], 313),
#  ([['BAKING SET PIECE RETROSPOT']], 576),
#  ([['BAKING SET SPACEBOY DESIGN']], 278),
#  ([['BATH BUILDING BLOCK WORD']], 155),
#  ([['BATHROOM METAL SIGN']], 218),
#  ([['BEWARE OF THE CAT METAL SIGN']], 168),
#  ([['BINGO SET']], 196),
#  ([['BISCUIT TIN CHRISTMAS']], 230),
#  ([['BISCUIT TIN VINTAGE CHRISTMAS']], 199),
#  ([['BLACKBLUE POLKADOT UMBRELLA']], 169),
#  ([['BLUE DINER WALL CLOCK']], 176),
#  ([['BLUE HAPPY BIRTHDAY BUNTING']], 221),
#  ([['BLUE HARMONICA IN BOX']], 291),
#  ([['BLUE POLKADOT WRAP']], 166),
#  ([['BLUE SPOT CERAMIC DRAWER KNOB']], 154),
#  ([['BLUE STRIPE CERAMIC DRAWER KNOB']], 162),
#  ([['BOX OF COCKTAIL PARASOLS']], 193),
#  ([['BOX OF MINI CRACKERS']], 300),
#  ([['BOX OF MINI VINTAGE CRACKERS']], 270),
#  ([['BOX OF VINTAGE ALPHABET BLOCKS']], 154),
#  ([['BREAD BIN DINER STYLE IVORY']], 202),
#  ([['BUNDLE OF ALPHABET EXERCISE BOOKS']], 224),
#  ([['BUNDLE OF RETRO NOTE BOOKS']], 178),
#  ([['CAKE CASES DOLLY GIRL DESIGN']], 223),
#  ([['CAKE CASES VINTAGE CHRISTMAS']], 310),
#  ([['CANDLEHOLDER PINK HANGING HEART']], 206),
#  ([['CARD BILLBOARD FONT']], 211),
#  ([['CARD CIRCUS PARADE']], 159),
#  ([['CERAMIC STRAWBERRY CAKE MONEY BANK']], 170),
#  ([['CHARLOTTE BAG APPLES DESIGN']], 199),
#  ([['CHARLOTTE BAG DOLLY GIRL DESIGN']], 164),
#  ([['CHARLOTTE BAG PINK POLKADOT']], 208),
#  ([['CHARLOTTE BAG SUKI DESIGN']], 239),
#  ([['CHARLOTTE BAG VINTAGE ALPHABET']], 192),
#  ([['CHICK GREY HOT WATER BOTTLE']], 162),
#  ([['CHILDRENS APRON APPLES DESIGN']], 194),
#  ([['CHILDRENS APRON DOLLY GIRL']], 177),
#  ([['CHILDRENS APRON SPACEBOY DESIGN']], 282),
#  ([['CHILDRENS CUTLERY DOLLY GIRL']], 196),
#  ([['CHILDRENS CUTLERY POLKADOT BLUE']], 150),
#  ([['CHILDRENS CUTLERY POLKADOT PINK']], 208),
#  ([['CHILDRENS CUTLERY RETROSPOT RED']], 157),
#  ([['CHILDRENS CUTLERY SPACEBOY']], 224),
#  ([['CHILLI LIGHTS']], 197),
#  ([['CHOCOLATE BOX RIBBONS']], 154),
#  ([['CHOCOLATE HOT WATER BOTTLE']], 336),
#  ([['CHOCOLATE THIS WAY METAL SIGN']], 208),
#  ([['CHRISTMAS CRAFT LITTLE FRIENDS']], 290),
#  ([['CHRISTMAS CRAFT TREE TOP ANGEL']], 235),
#  ([['CHRISTMAS CRAFT WHITE FAIRY']], 240),
#  ([['CHRISTMAS GLASS BALL LIGHTS']], 152),
#  ([['CHRISTMAS LIGHTS REINDEER']], 170),
#  ([['CHRISTMAS STAR WISH LIST CHALKBOARD']], 195),
#  ([['CIRCUS PARADE LUNCH BOX']], 160),
#  ([['CLASSIC GLASS COOKIE JAR']], 189),
#  ([['CLASSIC METAL BIRDCAGE PLANT HOLDER']], 167),
#  ([['CLEAR DRAWER KNOB ACRYLIC EDWARDIAN']], 164),
#  ([['CLOTHES PEGS RETROSPOT PACK']], 334),
#  ([['COFFEE MUG APPLES DESIGN']], 153),
#  ([['COLOUR GLASS TLIGHT HOLDER HANGING']], 310),
#  ([['COLOUR SPACEBOY PEN']], 161),
#  ([['COOK WITH WINE METAL SIGN']], 273),
#  ([['CREAM HEART CARD HOLDER']], 264),
#  ([['CREAM SWEETHEART MINI CHEST']], 284),
#  ([['DECORATIVE WICKER HEART LARGE']], 168),
#  ([['DECORATIVE WICKER HEART MEDIUM']], 158),
#  ([['DOILIES VINTAGE CHRISTMAS']], 151),
#  ([['DOLLY GIRL LUNCH BOX']], 276),
#  ([['DOORMAT ENGLISH ROSE']], 216),
#  ([['DOORMAT FANCY FONT HOME SWEET HOME']], 191),
#  ([['DOORMAT HEARTS']], 273),
#  ([['DOORMAT HOME SWEET HOME BLUE']], 192),
#  ([['DOORMAT KEEP CALM AND COME IN']], 376),
#  ([['DOORMAT NEW ENGLAND']], 303),
#  ([['DOORMAT RED RETROSPOT']], 306),
#  ([['DOORMAT SPOTTY HOME SWEET HOME']], 236),
#  ([['DOORMAT UNION FLAG']], 290),
#  ([['DOORMAT WELCOME PUPPIES']], 155),
#  ([['DOORMAT WELCOME TO OUR HOME']], 226),
#  ([['DOORSTOP RETROSPOT HEART']], 163),
#  ([['DOUGHNUT LIP GLOSS']], 215),
#  ([['EDWARDIAN PARASOL NATURAL']], 176),
#  ([['ENAMEL BREAD BIN CREAM']], 180),
#  ([['ENAMEL FLOWER JUG CREAM']], 303),
#  ([['ENAMEL MEASURING JUG CREAM']], 218),
#  ([['ENGLISH ROSE HOT WATER BOTTLE']], 168),
#  ([['FAMILY ALBUM WHITE PICTURE FRAME']], 160),
#  ([['FAMILY PHOTO FRAME CORNICE']], 165),
#  ([['FANCY FONT BIRTHDAY CARD']], 160),
#  ([['FANCY FONTS BIRTHDAY WRAP']], 177),
#  ([['FAWN BLUE HOT WATER BOTTLE']], 207),
#  ([['FELTCRAFT BUTTERFLY HEARTS']], 267),
#  ([['FELTCRAFT CHRISTMAS FAIRY']], 201),
#  ([['FELTCRAFT CUSHION BUTTERFLY']], 174),
#  ([['FELTCRAFT CUSHION OWL']], 217),
#  ([['FELTCRAFT CUSHION RABBIT']], 174),
#  ([['FELTCRAFT DOLL EMILY']], 153),
#  ([['FELTCRAFT DOLL MOLLY']], 195),
#  ([['FELTCRAFT DOLL ROSIE']], 170),
#  ([['FELTCRAFT FLOWER FRIENDS']], 310),
#  ([['FELTCRAFT GIRL AMELIE KIT']], 187),
#  ([['FELTCRAFT PRINCESS CHARLOTTE DOLL']], 252),
#  ([['FELTCRAFT PRINCESS LOLA DOLL']], 225),
#  ([['FELTCRAFT PRINCESS OLIVIA DOLL']], 168),
#  ([['FRENCH ENAMEL CANDLEHOLDER']], 154),
#  ([['GARDENERS KNEELING PAD CUP OF TEA']], 351),
#  ([['GARDENERS KNEELING PAD KEEP CALM']], 405),
#  ([['GIANT CHRISTMAS CRACKER']], 260),
#  ([['GIFT TAGS CHRISTMAS']], 234),
#  ([['GIFT TAGS VINTAGE CHRISTMAS']], 226),
#  ([['GIN TONIC DIET METAL SIGN']], 313),
#  ([['GINGERBREAD MAN COOKIE CUTTER']], 364),
#  ([['GINGHAM HEART DECORATION']], 251),
#  ([['GIRAFFE WOODEN RULER']], 185),
#  ([['GLASS APOTHECARY BOTTLE PERFUME']], 151),
#  ([['GRAND CHOCOLATECANDLE']], 172),
#  ([['GREEN REGENCY TEACUP AND SAUCER']], 374),
#  ([['GREY HEART HOT WATER BOTTLE']], 293),
#  ([['GROW A FLYTRAP OR SUNFLOWER IN TIN']], 163),
#  ([['GUMBALL COAT RACK']], 246),
#  ([['HAND OVER THE CHOCOLATE SIGN']], 259),
#  ([['HAND WARMER BIRD DESIGN']], 279),
#  ([['HAND WARMER OWL DESIGN']], 340),
#  ([['HAND WARMER RED LOVE HEART']], 268),
#  ([['HAND WARMER RED RETROSPOT']], 224),
#  ([['HAND WARMER SCOTTY DOG DESIGN']], 289),
#  ([['HAND WARMER UNION JACK']], 259),
#  ([['HANGING HEART JAR TLIGHT HOLDER']], 295),
#  ([['HANGING HEART ZINC TLIGHT HOLDER']], 260),
#  ([['HANGING JAM JAR TLIGHT HOLDER']], 191),
#  ([['HANGING METAL HEART LANTERN']], 183),
#  ([['HAPPY STENCIL CRAFT']], 156),
#  ([['HEART IVORY TRELLIS LARGE']], 178),
#  ([['HEART OF WICKER LARGE']], 440),
#  ([['HEART OF WICKER SMALL']], 529),
#  ([['HEARTS HANGING DECORATION RUSTIC']], 167),
#  ([['HOME BUILDING BLOCK WORD']], 347),
#  ([['HOME SWEET HOME CUSHION COVER']], 165),
#  ([['HOME SWEET HOME METAL SIGN']], 159),
#  ([['HOME SWEET HOME MUG']], 161),
#  ([['HOMEMADE JAM SCENTED CANDLES']], 382),
#  ([['HOOK PHOTO SHELF ANTIQUE WHITE']], 167),
#  ([['HOT BATHS METAL SIGN']], 198),
#  ([['HOT WATER BOTTLE I AM SO POORLY']], 282),
#  ([['HOT WATER BOTTLE KEEP CALM']], 473),
#  ([['HOT WATER BOTTLE TEA AND SYMPATHY']], 297),
#  ([['ICE CREAM PEN LIP GLOSS']], 158),
#  ([['ICE CREAM SUNDAE LIP GLOSS']], 202),
#  ([['IM ON HOLIDAY METAL SIGN']], 201),
#  ([['IVORY DINER WALL CLOCK']], 232),
#  ([['IVORY KITCHEN SCALES']], 354),
#  ([['IVORY WICKER HEART LARGE']], 207),
#  ([['IVORY WICKER HEART MEDIUM']], 179),
#  ([['JAM JAR WITH PINK LID']], 161),
#  ([['JAM MAKING SET PRINTED']], 477),
#  ([['JAM MAKING SET WITH JARS']], 530),
#  ([['JAZZ HEARTS PURSE NOTEBOOK']], 158),
#  ([['JINGLE BELL HEART ANTIQUE SILVER']], 162),
#  ([['JINGLE BELL HEART DECORATION']], 223),
#  ([['JUMBO BAG ALPHABET']], 396),
#  ([['JUMBO BAG APPLES']], 344),
#  ([['JUMBO BAG BAROQUE BLACK WHITE']], 294),
#  ([['JUMBO BAG CHRISTMAS']], 389),
#  ([['JUMBO BAG DOILEY PATTERNS']], 299),
#  ([['JUMBO BAG DOLLY GIRL DESIGN']], 164),
#  ([['JUMBO BAG OWLS']], 190),
#  ([['JUMBO BAG PAISLEY PARK']], 230),
#  ([['JUMBO BAG PEARS']], 261),
#  ([['JUMBO BAG PINK POLKADOT']], 356),
#  ([['JUMBO BAG PINK VINTAGE PAISLEY']], 292),
#  ([['JUMBO BAG RED RETROSPOT']], 609),
#  ([['JUMBO BAG SCANDINAVIAN BLUE PAISLEY']], 232),
#  ([['JUMBO BAG SPACEBOY DESIGN']], 242),
#  ([['JUMBO BAG STRAWBERRY']], 302),
#  ([['JUMBO BAG VINTAGE CHRISTMAS']], 283),
#  ([['JUMBO BAG VINTAGE DOILY']], 361),
#  ([['JUMBO BAG VINTAGE LEAF']], 376),
#  ([['JUMBO BAG WOODLAND ANIMALS']], 242),
#  ([['JUMBO SHOPPER VINTAGE RED PAISLEY']], 354),
#  ([['JUMBO STORAGE BAG SKULLS']], 208),
#  ([['JUMBO STORAGE BAG SUKI']], 313),
#  ([['KEY FOB SHED']], 157),
#  ([['KNITTED UNION FLAG HOT WATER BOTTLE']], 168),
#  ([['LADIES GENTLEMEN METAL SIGN']], 181),
#  ([['LANTERN CREAM GAZEBO']], 176),
#  ([['LARGE CERAMIC TOP STORAGE JAR']], 166),
#  ([['LARGE WHITE HEART OF WICKER']], 350),
#  ([['LONDON BUS COFFEE MUG']], 175),
#  ([['LOVE BUILDING BLOCK WORD']], 319),
#  ([['LOVE HOT WATER BOTTLE']], 315),
#  ([['LOVEBIRD HANGING DECORATION WHITE']], 174),
#  ([['LUNCH BAG ALPHABET DESIGN']], 377),
#  ([['LUNCH BAG APPLE DESIGN']], 400),
#  ([['LUNCH BAG BLACK SKULL']], 449),
#  ([['LUNCH BAG CARS BLUE']], 466),
#  ([['LUNCH BAG DOILEY PATTERN']], 290),
#  ([['LUNCH BAG DOLLY GIRL DESIGN']], 301),
#  ([['LUNCH BAG PAISLEY PARK']], 233),
#  ([['LUNCH BAG PINK POLKADOT']], 436),
#  ([['LUNCH BAG RED RETROSPOT']], 518),
#  ([['LUNCH BAG SPACEBOY DESIGN']], 476),
#  ([['LUNCH BAG SUKI DESIGN']], 423),
#  ([['LUNCH BAG VINTAGE DOILY']], 318),
#  ([['LUNCH BAG VINTAGE LEAF DESIGN']], 305),
#  ([['LUNCH BAG WOODLAND']], 360),
#  ([['LUNCH BOX I LOVE LONDON']], 195),
#  ([['LUNCH BOX WITH CUTLERY RETROSPOT']], 174),
#  ([['MAGIC DRAWING SLATE SPACEBOY']], 157),
#  ([['MAGNETS PACK OF SWALLOWS']], 157),
#  ([['MEMO BOARD COTTAGE DESIGN']], 173),
#  ([['MEMO BOARD RETROSPOT DESIGN']], 223),
#  ([['METAL HOOK HANGER FRENCH CHATEAU']], 196),
#  ([['METAL SIGN TAKE IT OR LEAVE IT']], 219),
#  ([['MINI PAINT SET VINTAGE']], 196),
#  ([['MINT KITCHEN SCALES']], 181),
#  ([['MULTI COLOUR SILVER TLIGHT HOLDER']], 198),
#  ([['NATURAL SLATE CHALKBOARD LARGE']], 207),
#  ([['NATURAL SLATE HEART CHALKBOARD']], 556),
#  ([['NATURAL SLATE RECTANGLE CHALKBOARD']], 204),
#  ([['NO SINGING METAL SIGN']], 200),
#  ([['OPEN CLOSED METAL SIGN']], 263),
#  ([['PACK OF BIRDY GIFT TAGS']], 212),
#  ([['PACK OF DINOSAUR CAKE CASES']], 278),
#  ([['PACK OF HEARTS DESIGN TISSUES']], 246),
#  ([['PACK OF LONDON TISSUES']], 174),
#  ([['PACK OF MUSHROOM CAKE CASES']], 172),
#  ([['PACK OF NAPKINS PANTRY DESIGN']], 352),
#  ([['PACK OF NAPKINS RED APPLES']], 207),
#  ([['PACK OF PINK PAISLEY CAKE CASES']], 387),
#  ([['PACK OF RED RETROSPOT TISSUES']], 180),
#  ([['PACK OF RETROSPOT CAKE CASES']], 602),
#  ([['PACK OF SKULL CAKE CASES']], 283),
#  ([['PACK OF SPACEBOY CAKE CASES']], 254),
#  ([['PACK OF SUKI TISSUES']], 167),
#  ([['PACK OF TRADITIONAL CRAYONS']], 219),
#  ([['PAINTED METAL PEARS ASSORTED']], 245),
#  ([['PANTRY MAGNETIC SHOPPING LIST']], 258),
#  ([['PANTRY ROLLING PIN']], 151),
#  ([['PANTRY SCRUBBING BRUSH']], 198),
#  ([['PANTRY WASHING UP BRUSH']], 225),
#  ([['PAPER BUNTING RETROSPOT']], 316),
#  ([['PAPER CHAIN KIT CHRISTMAS']], 553),
#  ([['PAPER CHAIN KIT EMPIRE']], 273),
#  ([['PAPER CHAIN KIT RETROSPOT']], 276),
#  ([['PAPER CHAIN KIT VINTAGE CHRISTMAS']], 414),
#  ([['PARISIENNE JEWELLERY DRAWER']], 151),
#  ([['PARISIENNE KEY CABINET']], 150),
#  ([['PARTY BUNTING']], 699),
#  ([['PARTY METAL SIGN']], 231),
#  ([['PENCIL SMALL TUBE WOODLAND']], 177),
#  ([['PENCILS SMALL TUBE RED RETROSPOT']], 206),
#  ([['PENCILS SMALL TUBE SKULL']], 178),
#  ([['PENCILS TALL TUBE RED RETROSPOT']], 170),
#  ([['PENCILS TUBE RED RETROSPOT']], 153),
#  ([['PHOTO FRAME CORNICE']], 268),
#  ([['PICNIC BASKET WICKER LARGE']], 180),
#  ([['PICNIC BASKET WICKER SMALL']], 159),
#  ([['PICTURE DOMINOES']], 173),
#  ([['PIECE SPACEBOY COOKIE CUTTER SET']], 201),
#  ([['PIGGY BANK RETROSPOT']], 170),
#  ([['PINK BABY BUNTING']], 159),
#  ([['PINK BLUE FELT CRAFT TRINKET BOX']], 272),
#  ([['PINK CREAM FELT CRAFT TRINKET BOX']], 295),
#  ([['PINK FAIRY CAKE CHILDRENS APRON']], 240),
#  ([['PINK HAPPY BIRTHDAY BUNTING']], 232),
#  ([['PINK POLKADOT WRAP']], 158),
#  ([['PINK REGENCY TEACUP AND SAUCER']], 318),
#  ([['PINK VINTAGE PAISLEY PICNIC BAG']], 192),
#  ([['PLACE SETTING WHITE HEART']], 162),
#  ([['PLASTERS IN TIN CIRCUS PARADE']], 283),
#  ([['PLASTERS IN TIN SKULLS']], 257),
#  ([['PLASTERS IN TIN SPACEBOY']], 317),
#  ([['PLASTERS IN TIN STRONGMAN']], 274),
#  ([['PLASTERS IN TIN VINTAGE PAISLEY']], 288),
#  ([['PLASTERS IN TIN WOODLAND ANIMALS']], 331),
#  ([['PLAYING CARDS JUBILEE UNION JACK']], 164),
#  ([['PLAYING CARDS KEEP CALM CARRY ON']], 284),
#  ([['PLEASE ONE PERSON METAL SIGN']], 337),
#  ([['POLYESTER FILLER PAD']], 188),
#  ([['POPCORN HOLDER']], 295),
#  ([['POPPYS PLAYHOUSE BEDROOM']], 183),
#  ([['POPPYS PLAYHOUSE KITCHEN']], 203),
#  ([['POTTERING IN THE SHED METAL SIGN']], 218),
#  ([['QUEENS GUARD COFFEE MUG']], 160),
#  ([['RABBIT NIGHT LIGHT']], 449),
#  ([['RECIPE BOX BLUE SKETCHBOOK DESIGN']], 151),
#  ([['RECIPE BOX PANTRY YELLOW DESIGN']], 450),
#  ([['RECIPE BOX RETROSPOT']], 208),
#  ([['RECYCLING BAG RETROSPOT']], 175),
#  ([['RED DINER WALL CLOCK']], 204),
#  ([['RED HANGING HEART TLIGHT HOLDER']], 352),
#  ([['RED HARMONICA IN BOX']], 324),
#  ([['RED KITCHEN SCALES']], 274),
#  ([['RED RETROSPOT BOWL']], 178),
#  ([['RED RETROSPOT CAKE STAND']], 237),
#  ([['RED RETROSPOT CHARLOTTE BAG']], 327),
#  ([['RED RETROSPOT CUP']], 155),
#  ([['RED RETROSPOT MINI CASES']], 222),
#  ([['RED RETROSPOT OVEN GLOVE']], 167),
#  ([['RED RETROSPOT PEG BAG']], 195),
#  ([['RED RETROSPOT PICNIC BAG']], 220),
#  ([['RED RETROSPOT ROUND CAKE TINS']], 156),
#  ([['RED RETROSPOT SHOPPER BAG']], 229),
#  ([['RED RETROSPOT SMALL MILK JUG']], 203),
#  ([['RED RETROSPOT UMBRELLA']], 198),
#  ([['RED RETROSPOT WRAP']], 231),
#  ([['RED SPOT CERAMIC DRAWER KNOB']], 153),
#  ([['RED STRIPE CERAMIC DRAWER KNOB']], 164),
#  ([['RED TOADSTOOL LED NIGHT LIGHT']], 257),
#  ([['RED WOOLLY HOTTIE WHITE HEART']], 167),
#  ([['REGENCY CAKESTAND TIER']], 836),
#  ([['REGENCY MILK JUG PINK']], 206),
#  ([['REGENCY SUGAR BOWL GREEN']], 190),
#  ([['REGENCY TEA PLATE GREEN']], 195),
#  ([['REGENCY TEA PLATE PINK']], 160),
#  ([['REGENCY TEA PLATE ROSES']], 223),
#  ([['REGENCY TEAPOT ROSES']], 247),
#  ([['RETROSPOT CHILDRENS APRON']], 187),
#  ([['RETROSPOT HEART HOT WATER BOTTLE']], 318),
#  ([['RETROSPOT LARGE MILK JUG']], 195),
#  ([['RETROSPOT PARTY BAG STICKER SET']], 159),
#  ([['RETROSPOT TEA SET CERAMIC PC']], 486),
#  ([['REVOLVER WOODEN RULER']], 216),
#  ([['REX CASHCARRY JUMBO SHOPPER']], 447),
#  ([['RIBBON REEL HEARTS DESIGN']], 179),
#  ([['RIBBON REEL STRIPES DESIGN']], 225),
#  ([['RIBBONS RUSTIC CHARM']], 389),
#  ([['ROBOT BIRTHDAY CARD']], 169),
#  ([['ROLL WRAP CHRISTMAS']], 241),
#  ([['ROLL WRAP RED CHRISTMAS']], 151),
#  ([['ROLL WRAP VINTAGE CHRISTMAS']], 213),
#  ([['ROLL WRAP VINTAGE SPOT']], 204),
#  ([['ROMANTIC PINKS RIBBONS']], 153),
#  ([['ROSES REGENCY TEACUP AND SAUCER']], 408),
#  ([['ROTATING SILVER ANGELS TLIGHT HLDR']], 175),
#  ([['ROUND CAKE TIN VINTAGE RED']], 182),
#  ([['ROUND SNACK BOXES SET OF FRUITS']], 211),
#  ([['ROUND SNACK BOXES SET OF WOODLAND']], 264),
#  ([['SCANDINAVIAN PAISLEY PICNIC BAG']], 216),
#  ([['SCANDINAVIAN REDS RIBBONS']], 221),
#  ([['SCOTTIE DOG HOT WATER BOTTLE']], 358),
#  ([['SET BABUSHKA NESTING BOXES']], 161),
#  ([['SET BLUE POLKADOT PARTY CANDLES']], 172),
#  ([['SET COLOUR PENCILS DOLLY GIRL']], 192),
#  ([['SET COLOUR PENCILS LOVE LONDON']], 157),
#  ([['SET COLOUR PENCILS SPACEBOY']], 258),
#  ([['SET COLOURING PENCILS DOILY']], 174),
#  ([['SET KIDS COLOUR CHALK STICKS']], 181),
#  ([['SET NAPKINS FAIRY CAKES DESIGN']], 186),
#  ([['SET OF BUTTERFLY COOKIE CUTTERS']], 317),
#  ([['SET OF CAKE TINS PANTRY DESIGN']], 621),
#  ([['SET OF CAKE TINS SKETCHBOOK']], 175),
#  ([['SET OF DOILIES PANTRY DESIGN']], 172),
#  ([['SET OF FAIRY CAKE BAKING CASES']], 321),
#  ([['SET OF HANGING OWLS OLLIE BEAK']], 169),
#  ([['SET OF HEART COOKIE CUTTERS']], 357),
#  ([['SET OF HERB TINS SKETCHBOOK']], 164),
#  ([['SET OF I LOVE LONDON CAKE CASES']], 177),
#  ([['SET OF KIDS COOKIE CUTTERS']], 272),
#  ([['SET OF KNICK KNACK TINS DOILY']], 230),
#  ([['SET OF LED DOLLY LIGHTS']], 271),
#  ([['SET OF MINI LOAF BAKING CASES']], 250),
#  ([['SET OF NOTEBOOKS IN PARCEL']], 226),
#  ([['SET OF PAISLEY FLOWER DOILIES']], 172),
#  ([['SET OF PANTRY DESIGN CAKE CASES']], 366),
#  ([['SET OF PANTRY JELLY MOULDS']], 430),
#  ([['SET OF PINK HEART PAPER DOILIES']], 201),
#  ([['SET OF REGENCY CAKE TINS']], 470),
#  ([['SET OF RETROSPOT PAPER DOILIES']], 230),
#  ([['SET OF RIBBONS VINTAGE CHRISTMAS']], 275),
#  ([['SET OF SNACK LOAF BAKING CASES']], 214),
#  ([['SET OF SOLDIER SKITTLES']], 230),
#  ([['SET OF SPICE TINS PANTRY DESIGN']], 379),
#  ([['SET OF TEA COFFEE SUGAR TINS PANTRY']], 273),
#  ([['SET OF TEA TIME BAKING CASES']], 243),
#  ([['SET OF TEA TOWELS APPLE AND PEARS']], 157),
#  ([['SET OF TEATIME PAPER DOILIES']], 193),
#  ([['SET OF VINTAGE CHRISTMAS NAPKINS']], 322),
#  ([['SET OF VINTAGE LEAF CAKE CASES']], 209),
#  ([['SET OF WOODEN HEART DECORATIONS']], 267),
#  ([['SET OF WOODEN SLEIGH DECORATIONS']], 177),
#  ([['SET OF WOODEN STOCKING DECORATION']], 200),
#  ([['SET OF WOODEN TREE DECORATIONS']], 179),
#  ([['SET PANTRY DESIGN TEA TOWELS']], 239),
#  ([['SET PAPER TABLE LANTERN HEARTS']], 205),
#  ([['SET PAPER TABLE LANTERN STARS']], 160),
#  ([['SET PAPER VINTAGE CHICK PAPER EGG']], 179),
#  ([['SET PINK POLKADOT PARTY CANDLES']], 202),
#  ([['SET RED GINGHAM ROSE STORAGE BOX']], 171),
#  ([['SET RED POLKADOT PARTY CANDLES']], 228),
#  ([['SET RED RETROSPOT LID GLASS BOWLS']], 340),
#  ([['SET RED RETROSPOT PAPER NAPKINS']], 404),
#  ([['SET RED SPOTTY PAPER CUPS']], 162),
#  ([['SET RED SPOTTY PAPER PLATES']], 173),
#  ([['SET SCHOOL MILK BOTTLES IN CRATE']], 195),
#  ([['SET TEA TOWELS I LOVE LONDON']], 176),
#  ([['SILVER BELLS TABLE DECORATION']], 180),
#  ([['SILVER STARS TABLE DECORATION']], 175),
#  ([['SINGLE ANTIQUE ROSE HOOK IVORY']], 169),
#  ([['SINGLE HEART ZINC TLIGHT HOLDER']], 218),
#  ([['SKULL LUNCH BOX WITH CUTLERY']], 161),
#  ([['SMALL DOLLY MIX DESIGN ORANGE BOWL']], 189),
#  ([['SMALL GLASS HEART TRINKET POT']], 207),
#  ([['SMALL MARSHMALLOWS PINK BOWL']], 164),
#  ([['SMALL POPCORN HOLDER']], 198),
#  ([['SMALL WHITE HEART OF WICKER']], 378),
#  ([['SOLDIERS EGG CUP']], 163),
#  ([['SPACEBOY BIRTHDAY CARD']], 226),
#  ([['SPACEBOY LUNCH BOX']], 311),
#  ([['SPACEBOY MINI BACKPACK']], 157),
#  ([['SPOTTY BUNTING']], 571),
#  ([['STRAWBERRY CERAMIC TRINKET BOX']], 268),
#  ([['STRAWBERRY CHARLOTTE BAG']], 226),
#  ([['STRAWBERRY LUNCH BOX WITH CUTLERY']], 227),
#  ([['STRIPEY MICE FELTCRAFT']], 262),
#  ([['SWALLOWS GREETING CARD']], 167),
#  ([['SWEETHEART CAKESTAND TIER']], 232),
#  ([['SWEETHEART CERAMIC TRINKET BOX']], 192),
#  ([['SWEETHEART FAIRY CAKE CASES']], 303),
#  ([['SWEETHEART RECIPE BOOK STAND']], 160),
#  ([['TEA PARTY BIRTHDAY CARD']], 176),
#  ([['TEA TIME PARTY BUNTING']], 186),
#  ([['TEATIME FAIRY CAKE CASES']], 387),
#  ([['TLIGHT GLASS FLUTED ANTIQUE']], 162),
#  ([['TOILET METAL SIGN']], 162),
#  ([['TRADITIONAL BISCUIT CUTTERS SET']], 155),
#  ([['TRADITIONAL CHRISTMAS RIBBONS']], 181),
#  ([['TRADITIONAL KNITTING NANCY']], 355),
#  ([['TRADITIONAL MODELLING CLAY']], 213),
#  ([['TRADITIONAL NAUGHTS CROSSES']], 195),
#  ([['TRADITIONAL PICK UP STICKS GAME']], 203),
#  ([['TRADITIONAL SPINNING TOPS']], 247),
#  ([['TRADITIONAL WOODEN CATCH CUP GAME']], 211),
#  ([['TRADITIONAL WOODEN SKIPPING ROPE']], 247),
#  ([['TRADTIONAL ALPHABET STAMP SET']], 152),
#  ([['TRAVEL CARD WALLET KEEP CALM']], 216),
#  ([['TRAVEL CARD WALLET VINTAGE TICKET']], 155),
#  ([['TRAVEL SEWING KIT']], 235),
#  ([['TREASURE ISLAND BOOK BOX']], 173),
#  ([['TREASURE TIN GYMKHANA DESIGN']], 183),
#  ([['VICTORIAN GLASS HANGING TLIGHT']], 390),
#  ([['VINTAGE CHRISTMAS BUNTING']], 253),
#  ([['VINTAGE CHRISTMAS GIFT SACK']], 168),
#  ([['VINTAGE CHRISTMAS STOCKING']], 245),
#  ([['VINTAGE CREAM DOG FOOD CONTAINER']], 169),
#  ([['VINTAGE DOILY JUMBO BAG RED']], 186),
#  ([['VINTAGE DOILY TRAVEL SEWING KIT']], 282),
#  ([['VINTAGE DONKEY TAIL GAME']], 181),
#  ([['VINTAGE HEADS AND TAILS CARD GAME']], 313),
#  ([['VINTAGE LEAF MAGNETIC NOTEPAD']], 159),
#  ([['VINTAGE PAISLEY STATIONERY SET']], 153),
#  ([['VINTAGE SNAKES LADDERS']], 193),
#  ([['VINTAGE SNAP CARDS']], 423),
#  ([['VINTAGE UNION JACK BUNTING']], 256),
#  ([['WASHROOM METAL SIGN']], 176),
#  ([['WATERING CAN BLUE ELEPHANT']], 158),
#  ([['WATERING CAN PINK BUNNY']], 153),
#  ([['WHITE HANGING HEART TLIGHT HOLDER']], 816),
#  ([['WHITE SKULL HOT WATER BOTTLE']], 205),
#  ([['WHITE SPOT RED CERAMIC DRAWER KNOB']], 152),
#  ([['WHITE WICKER STAR']], 210),
#  ([['WHITE WOOD GARDEN PLANT LADDER']], 266),
#  ([['WICKER STAR']], 193),
#  ([['WOOD BLACK BOARD ANT WHITE FINISH']], 273),
#  ([['WOOD DRAWER CABINET WHITE FINISH']], 225),
#  ([['WOOD S CABINET ANT WHITE FINISH']], 168),
#  ([['WOODEN BOX OF DOMINOES']], 311),
#  ([['WOODEN CROQUET GARDEN SET']], 172),
#  ([['WOODEN FRAME ANTIQUE WHITE']], 369),
#  ([['WOODEN HEART CHRISTMAS SCANDINAVIAN']], 331),
#  ([['WOODEN PICTURE FRAME WHITE FINISH']], 397),
#  ([['WOODEN ROUNDERS GARDEN SET']], 214),
#  ([['WOODEN SCHOOL COLOURING SET']], 272),
#  ([['WOODEN STAR CHRISTMAS SCANDINAVIAN']], 318),
#  ([['WOODEN TREE CHRISTMAS SCANDINAVIAN']], 213),
#  ([['WOODEN UNION JACK BUNTING']], 209),
#  ([['WOODLAND CHARLOTTE BAG']], 232),
#  ([['WORLD WAR GLIDERS ASSTD DESIGNS']], 294),
#  ([['WRAP ALPHABET DESIGN']], 176),
#  ([['WRAP ENGLISH ROSE']], 186),
#  ([['YOURE CONFUSING ME METAL SIGN']], 179),
#  ([['ZINC FOLKART SLEIGH BELLS']], 268),
#  ([['ZINC HERB GARDEN CONTAINER']], 154),
#  ([['ZINC METAL HEART DECORATION']], 288),
#  ([['ZINC TLIGHT HOLDER STARS SMALL']], 179),
#  ([['ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE PINK']], 168),
#  ([['ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE RED']], 231),
#  ([['ALARM CLOCK BAKELIKE IVORY', 'ALARM CLOCK BAKELIKE RED']], 168),
#  ([['ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE RED']], 198),
#  ([['ASSORTED COLOUR BIRD ORNAMENT', 'PAINTED METAL PEARS ASSORTED']], 172),
#  ([['ASSORTED COLOUR BIRD ORNAMENT', 'REGENCY CAKESTAND TIER']], 158),
#  ([['ASSORTED COLOUR BIRD ORNAMENT', 'WHITE HANGING HEART TLIGHT HOLDER']],
#   165),
#  ([['BAKING SET PIECE RETROSPOT', 'BAKING SET SPACEBOY DESIGN']], 230),
#  ([['BAKING SET PIECE RETROSPOT', 'RETROSPOT TEA SET CERAMIC PC']], 167),
#  ([['BLUE HAPPY BIRTHDAY BUNTING', 'PINK HAPPY BIRTHDAY BUNTING']], 182),
#  ([['BLUE HARMONICA IN BOX', 'RED HARMONICA IN BOX']], 162),
#  ([['CANDLEHOLDER PINK HANGING HEART', 'WHITE HANGING HEART TLIGHT HOLDER']],
#   164),
#  ([['CHILDRENS CUTLERY DOLLY GIRL', 'CHILDRENS CUTLERY SPACEBOY']], 157),
#  ([['CHOCOLATE HOT WATER BOTTLE', 'HOT WATER BOTTLE I AM SO POORLY']], 163),
#  ([['CHOCOLATE HOT WATER BOTTLE', 'HOT WATER BOTTLE KEEP CALM']], 161),
#  ([['CHOCOLATE HOT WATER BOTTLE', 'HOT WATER BOTTLE TEA AND SYMPATHY']], 158),
#  ([['CHRISTMAS CRAFT LITTLE FRIENDS', 'CHRISTMAS CRAFT WHITE FAIRY']], 153),
#  ([['DOLLY GIRL LUNCH BOX', 'SPACEBOY LUNCH BOX']], 210),
#  ([['FELTCRAFT PRINCESS CHARLOTTE DOLL', 'FELTCRAFT PRINCESS LOLA DOLL']],
#   154),
#  ([['GARDENERS KNEELING PAD CUP OF TEA', 'GARDENERS KNEELING PAD KEEP CALM']],
#   254),
#  ([['GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER']],
#   281),
#  ([['GREEN REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND TIER']], 235),
#  ([['GREEN REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER']],
#   303),
#  ([['HAND WARMER BIRD DESIGN', 'HAND WARMER OWL DESIGN']], 175),
#  ([['HAND WARMER BIRD DESIGN', 'HAND WARMER SCOTTY DOG DESIGN']], 151),
#  ([['HAND WARMER OWL DESIGN', 'HAND WARMER RED LOVE HEART']], 151),
#  ([['HAND WARMER OWL DESIGN', 'HAND WARMER SCOTTY DOG DESIGN']], 171),
#  ([['HEART OF WICKER LARGE', 'HEART OF WICKER SMALL']], 244),
#  ([['HEART OF WICKER LARGE', 'LARGE WHITE HEART OF WICKER']], 153),
#  ([['HEART OF WICKER LARGE', 'WHITE HANGING HEART TLIGHT HOLDER']], 179),
#  ([['HEART OF WICKER SMALL', 'SMALL WHITE HEART OF WICKER']], 151),
#  ([['HEART OF WICKER SMALL', 'WHITE HANGING HEART TLIGHT HOLDER']], 166),
#  ([['HOME BUILDING BLOCK WORD', 'LOVE BUILDING BLOCK WORD']], 174),
#  ([['HOT WATER BOTTLE KEEP CALM', 'HOT WATER BOTTLE TEA AND SYMPATHY']], 160),
#  ([['HOT WATER BOTTLE KEEP CALM', 'LOVE HOT WATER BOTTLE']], 171),
#  ([['IVORY KITCHEN SCALES', 'RED KITCHEN SCALES']], 166),
#  ([['JAM MAKING SET PRINTED', 'JAM MAKING SET WITH JARS']], 197),
#  ([['JAM MAKING SET WITH JARS', 'SET OF CAKE TINS PANTRY DESIGN']], 177),
#  ([['JUMBO BAG ALPHABET', 'JUMBO BAG APPLES']], 158),
#  ([['JUMBO BAG ALPHABET', 'JUMBO BAG RED RETROSPOT']], 177),
#  ([['JUMBO BAG ALPHABET', 'JUMBO BAG VINTAGE LEAF']], 159),
#  ([['JUMBO BAG ALPHABET', 'LUNCH BAG ALPHABET DESIGN']], 162),
#  ([['JUMBO BAG APPLES', 'JUMBO BAG PEARS']], 177),
#  ([['JUMBO BAG APPLES', 'JUMBO BAG RED RETROSPOT']], 191),
#  ([['JUMBO BAG APPLES', 'JUMBO BAG VINTAGE LEAF']], 158),
#  ([['JUMBO BAG APPLES', 'LUNCH BAG APPLE DESIGN']], 175),
#  ([['JUMBO BAG BAROQUE BLACK WHITE', 'JUMBO BAG RED RETROSPOT']], 187),
#  ([['JUMBO BAG CHRISTMAS', 'JUMBO BAG VINTAGE CHRISTMAS']], 177),
#  ([['JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT']], 243),
#  ([['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT']], 176),
#  ([['JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY']], 201),
#  ([['JUMBO BAG RED RETROSPOT', 'JUMBO BAG VINTAGE DOILY']], 183),
#  ([['JUMBO BAG RED RETROSPOT', 'JUMBO BAG VINTAGE LEAF']], 180),
#  ([['JUMBO BAG RED RETROSPOT', 'JUMBO SHOPPER VINTAGE RED PAISLEY']], 184),
#  ([['JUMBO BAG RED RETROSPOT', 'JUMBO STORAGE BAG SUKI']], 189),
#  ([['JUMBO BAG RED RETROSPOT', 'LUNCH BAG PINK POLKADOT']], 159),
#  ([['JUMBO BAG RED RETROSPOT', 'LUNCH BAG RED RETROSPOT']], 210),
#  ([['JUMBO BAG VINTAGE DOILY', 'JUMBO BAG VINTAGE LEAF']], 154),
#  ([['JUMBO BAG VINTAGE DOILY', 'LUNCH BAG VINTAGE DOILY']], 151),
#  ([['LARGE WHITE HEART OF WICKER', 'SMALL WHITE HEART OF WICKER']], 205),
#  ([['LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG APPLE DESIGN']], 191),
#  ([['LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG BLACK SKULL']], 158),
#  ([['LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG CARS BLUE']], 160),
#  ([['LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG RED RETROSPOT']], 160),
#  ([['LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG SPACEBOY DESIGN']], 158),
#  ([['LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG SUKI DESIGN']], 160),
#  ([['LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG VINTAGE LEAF DESIGN']], 153),
#  ([['LUNCH BAG APPLE DESIGN', 'LUNCH BAG BLACK SKULL']], 172),
#  ([['LUNCH BAG APPLE DESIGN', 'LUNCH BAG CARS BLUE']], 171),
#  ([['LUNCH BAG APPLE DESIGN', 'LUNCH BAG PINK POLKADOT']], 164),
#  ([['LUNCH BAG APPLE DESIGN', 'LUNCH BAG RED RETROSPOT']], 195),
#  ([['LUNCH BAG APPLE DESIGN', 'LUNCH BAG SPACEBOY DESIGN']], 172),
#  ([['LUNCH BAG APPLE DESIGN', 'LUNCH BAG SUKI DESIGN']], 183),
#  ([['LUNCH BAG APPLE DESIGN', 'LUNCH BAG VINTAGE LEAF DESIGN']], 174),
#  ([['LUNCH BAG APPLE DESIGN', 'LUNCH BAG WOODLAND']], 159),
#  ([['LUNCH BAG BLACK SKULL', 'LUNCH BAG CARS BLUE']], 202),
#  ([['LUNCH BAG BLACK SKULL', 'LUNCH BAG PINK POLKADOT']], 228),
#  ([['LUNCH BAG BLACK SKULL', 'LUNCH BAG RED RETROSPOT']], 242),
#  ([['LUNCH BAG BLACK SKULL', 'LUNCH BAG SPACEBOY DESIGN']], 207),
#  ([['LUNCH BAG BLACK SKULL', 'LUNCH BAG SUKI DESIGN']], 216),
#  ([['LUNCH BAG BLACK SKULL', 'LUNCH BAG WOODLAND']], 174),
#  ([['LUNCH BAG CARS BLUE', 'LUNCH BAG PINK POLKADOT']], 236),
#  ([['LUNCH BAG CARS BLUE', 'LUNCH BAG RED RETROSPOT']], 244),
#  ([['LUNCH BAG CARS BLUE', 'LUNCH BAG SPACEBOY DESIGN']], 217),
#  ([['LUNCH BAG CARS BLUE', 'LUNCH BAG SUKI DESIGN']], 238),
#  ([['LUNCH BAG CARS BLUE', 'LUNCH BAG WOODLAND']], 191),
#  ([['LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG RED RETROSPOT']], 161),
#  ([['LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG SPACEBOY DESIGN']], 187),
#  ([['LUNCH BAG PINK POLKADOT', 'LUNCH BAG RED RETROSPOT']], 248),
#  ([['LUNCH BAG PINK POLKADOT', 'LUNCH BAG SPACEBOY DESIGN']], 193),
#  ([['LUNCH BAG PINK POLKADOT', 'LUNCH BAG SUKI DESIGN']], 199),
#  ([['LUNCH BAG PINK POLKADOT', 'LUNCH BAG WOODLAND']], 163),
#  ([['LUNCH BAG RED RETROSPOT', 'LUNCH BAG SPACEBOY DESIGN']], 234),
#  ([['LUNCH BAG RED RETROSPOT', 'LUNCH BAG SUKI DESIGN']], 239),
#  ([['LUNCH BAG RED RETROSPOT', 'LUNCH BAG WOODLAND']], 208),
#  ([['LUNCH BAG SPACEBOY DESIGN', 'LUNCH BAG SUKI DESIGN']], 228),
#  ([['LUNCH BAG SPACEBOY DESIGN', 'LUNCH BAG WOODLAND']], 216),
#  ([['LUNCH BAG SUKI DESIGN', 'LUNCH BAG WOODLAND']], 175),
#  ([['NATURAL SLATE HEART CHALKBOARD', 'WHITE HANGING HEART TLIGHT HOLDER']],
#   171),
#  ([['PACK OF DINOSAUR CAKE CASES', 'PACK OF RETROSPOT CAKE CASES']], 159),
#  ([['PACK OF PINK PAISLEY CAKE CASES', 'PACK OF RETROSPOT CAKE CASES']], 224),
#  ([['PACK OF PINK PAISLEY CAKE CASES', 'TEATIME FAIRY CAKE CASES']], 171),
#  ([['PACK OF RETROSPOT CAKE CASES', 'TEATIME FAIRY CAKE CASES']], 212),
#  ([['PAPER CHAIN KIT CHRISTMAS', 'PAPER CHAIN KIT VINTAGE CHRISTMAS']], 278),
#  ([['PARTY BUNTING', 'REGENCY CAKESTAND TIER']], 168),
#  ([['PARTY BUNTING', 'SPOTTY BUNTING']], 243),
#  ([['PARTY BUNTING', 'WHITE HANGING HEART TLIGHT HOLDER']], 173),
#  ([['PINK BLUE FELT CRAFT TRINKET BOX', 'PINK CREAM FELT CRAFT TRINKET BOX']],
#   150),
#  ([['PINK REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND TIER']], 208),
#  ([['PINK REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER']],
#   255),
#  ([['PLASTERS IN TIN CIRCUS PARADE', 'PLASTERS IN TIN WOODLAND ANIMALS']],
#   152),
#  ([['PLASTERS IN TIN SPACEBOY', 'PLASTERS IN TIN WOODLAND ANIMALS']], 172),
#  ([['POPPYS PLAYHOUSE BEDROOM', 'POPPYS PLAYHOUSE KITCHEN']], 154),
#  ([['RECIPE BOX PANTRY YELLOW DESIGN', 'SET OF CAKE TINS PANTRY DESIGN']],
#   187),
#  ([['RED HANGING HEART TLIGHT HOLDER', 'WHITE HANGING HEART TLIGHT HOLDER']],
#   253),
#  ([['REGENCY CAKESTAND TIER', 'REGENCY TEAPOT ROSES']], 155),
#  ([['REGENCY CAKESTAND TIER', 'ROSES REGENCY TEACUP AND SAUCER']], 254),
#  ([['REGENCY CAKESTAND TIER', 'SET OF CAKE TINS PANTRY DESIGN']], 154),
#  ([['REGENCY CAKESTAND TIER', 'SET OF REGENCY CAKE TINS']], 193),
#  ([['REGENCY CAKESTAND TIER', 'WHITE HANGING HEART TLIGHT HOLDER']], 155),
#  ([['REGENCY MILK JUG PINK', 'REGENCY SUGAR BOWL GREEN']], 162),
#  ([['REGENCY MILK JUG PINK', 'REGENCY TEAPOT ROSES']], 154),
#  ([['REGENCY SUGAR BOWL GREEN', 'REGENCY TEAPOT ROSES']], 154),
#  ([['REGENCY TEA PLATE GREEN', 'REGENCY TEA PLATE ROSES']], 165),
#  ([['SET OF BUTTERFLY COOKIE CUTTERS', 'SET OF HEART COOKIE CUTTERS']], 177),
#  ([['SET OF CAKE TINS PANTRY DESIGN', 'SET OF SPICE TINS PANTRY DESIGN']],
#   212),
#  ([['SET OF CAKE TINS PANTRY DESIGN', 'SET OF TEA COFFEE SUGAR TINS PANTRY']],
#   165),
#  ([['SET OF FAIRY CAKE BAKING CASES', 'SET OF MINI LOAF BAKING CASES']], 180),
#  ([['SET OF FAIRY CAKE BAKING CASES', 'SET OF SNACK LOAF BAKING CASES']], 158),
#  ([['SET OF FAIRY CAKE BAKING CASES', 'SET OF TEA TIME BAKING CASES']], 168),
#  ([['SET OF MINI LOAF BAKING CASES', 'SET OF SNACK LOAF BAKING CASES']], 150),
#  ([['SET OF MINI LOAF BAKING CASES', 'SET OF TEA TIME BAKING CASES']], 150),
#  ([['VINTAGE HEADS AND TAILS CARD GAME', 'VINTAGE SNAP CARDS']], 169),
#  ([['WHITE HANGING HEART TLIGHT HOLDER', 'WOODEN PICTURE FRAME WHITE FINISH']],
#   150),
#  ([['WOODEN FRAME ANTIQUE WHITE', 'WOODEN PICTURE FRAME WHITE FINISH']], 234),
#  ([['WOODEN HEART CHRISTMAS SCANDINAVIAN',
#     'WOODEN STAR CHRISTMAS SCANDINAVIAN']],
#   240),
#  ([['WOODEN HEART CHRISTMAS SCANDINAVIAN',
#     'WOODEN TREE CHRISTMAS SCANDINAVIAN']],
#   158),
#  ([['WOODEN STAR CHRISTMAS SCANDINAVIAN',
#     'WOODEN TREE CHRISTMAS SCANDINAVIAN']],
#   179),
#  ([['ALARM CLOCK BAKELIKE GREEN'], ['ALARM CLOCK BAKELIKE RED']], 159),
#  ([['ALARM CLOCK BAKELIKE RED'], ['ALARM CLOCK BAKELIKE GREEN']], 155),
#  ([['ALARM CLOCK BAKELIKE RED'], ['ALARM CLOCK BAKELIKE RED']], 182),
#  ([['ASSORTED COLOUR BIRD ORNAMENT'], ['ASSORTED COLOUR BIRD ORNAMENT']], 275),
#  ([['HEART OF WICKER SMALL'], ['HEART OF WICKER SMALL']], 176),
#  ([['HEART OF WICKER SMALL'], ['WHITE HANGING HEART TLIGHT HOLDER']], 157),
#  ([['JUMBO BAG ALPHABET'], ['JUMBO BAG ALPHABET']], 157),
#  ([['JUMBO BAG ALPHABET'], ['JUMBO BAG RED RETROSPOT']], 158),
#  ([['JUMBO BAG APPLES'], ['JUMBO BAG RED RETROSPOT']], 163),
#  ([['JUMBO BAG PINK POLKADOT'], ['JUMBO BAG PINK POLKADOT']], 156),
#  ([['JUMBO BAG PINK POLKADOT'], ['JUMBO BAG RED RETROSPOT']], 183),
#  ([['JUMBO BAG RED RETROSPOT'], ['JUMBO BAG ALPHABET']], 166),
#  ([['JUMBO BAG RED RETROSPOT'], ['JUMBO BAG APPLES']], 183),
#  ([['JUMBO BAG RED RETROSPOT'], ['JUMBO BAG CHRISTMAS']], 163),
#  ([['JUMBO BAG RED RETROSPOT'], ['JUMBO BAG PINK POLKADOT']], 176),
#  ([['JUMBO BAG RED RETROSPOT'], ['JUMBO BAG RED RETROSPOT']], 302),
#  ([['JUMBO BAG RED RETROSPOT'], ['JUMBO BAG VINTAGE DOILY']], 178),
#  ([['JUMBO BAG RED RETROSPOT'], ['JUMBO BAG VINTAGE LEAF']], 166),
#  ([['JUMBO BAG RED RETROSPOT'], ['LUNCH BAG BLACK SKULL']], 156),
#  ([['JUMBO BAG RED RETROSPOT'], ['LUNCH BAG PINK POLKADOT']], 154),
#  ([['JUMBO BAG RED RETROSPOT'], ['LUNCH BAG RED RETROSPOT']], 188),
#  ([['JUMBO BAG VINTAGE LEAF'], ['JUMBO BAG VINTAGE LEAF']], 151),
#  ([['JUMBO SHOPPER VINTAGE RED PAISLEY'], ['JUMBO BAG RED RETROSPOT']], 153),
#  ([['JUMBO STORAGE BAG SUKI'], ['JUMBO BAG RED RETROSPOT']], 151),
#  ([['LUNCH BAG ALPHABET DESIGN'], ['LUNCH BAG RED RETROSPOT']], 156),
#  ([['LUNCH BAG APPLE DESIGN'], ['LUNCH BAG APPLE DESIGN']], 186),
#  ([['LUNCH BAG APPLE DESIGN'], ['LUNCH BAG RED RETROSPOT']], 171),
#  ([['LUNCH BAG BLACK SKULL'], ['LUNCH BAG ALPHABET DESIGN']], 152),
#  ([['LUNCH BAG BLACK SKULL'], ['LUNCH BAG APPLE DESIGN']], 151),
#  ([['LUNCH BAG BLACK SKULL'], ['LUNCH BAG BLACK SKULL']], 221),
#  ([['LUNCH BAG BLACK SKULL'], ['LUNCH BAG CARS BLUE']], 169),
#  ([['LUNCH BAG BLACK SKULL'], ['LUNCH BAG PINK POLKADOT']], 171),
#  ([['LUNCH BAG BLACK SKULL'], ['LUNCH BAG RED RETROSPOT']], 204),
#  ([['LUNCH BAG BLACK SKULL'], ['LUNCH BAG SPACEBOY DESIGN']], 163),
#  ([['LUNCH BAG BLACK SKULL'], ['LUNCH BAG SUKI DESIGN']], 181),
#  ([['LUNCH BAG BLACK SKULL'], ['LUNCH BAG WOODLAND']], 150),
#  ([['LUNCH BAG CARS BLUE'], ['JUMBO BAG RED RETROSPOT']], 155),
#  ([['LUNCH BAG CARS BLUE'], ['LUNCH BAG ALPHABET DESIGN']], 154),
#  ([['LUNCH BAG CARS BLUE'], ['LUNCH BAG APPLE DESIGN']], 156),
#  ([['LUNCH BAG CARS BLUE'], ['LUNCH BAG BLACK SKULL']], 178),
#  ([['LUNCH BAG CARS BLUE'], ['LUNCH BAG CARS BLUE']], 197),
#  ([['LUNCH BAG CARS BLUE'], ['LUNCH BAG PINK POLKADOT']], 176),
#  ([['LUNCH BAG CARS BLUE'], ['LUNCH BAG RED RETROSPOT']], 188),
#  ([['LUNCH BAG CARS BLUE'], ['LUNCH BAG SPACEBOY DESIGN']], 161),
#  ([['LUNCH BAG CARS BLUE'], ['LUNCH BAG SUKI DESIGN']], 178),
#  ([['LUNCH BAG PINK POLKADOT'], ['JUMBO BAG RED RETROSPOT']], 159),
#  ([['LUNCH BAG PINK POLKADOT'], ['LUNCH BAG ALPHABET DESIGN']], 150),
#  ([['LUNCH BAG PINK POLKADOT'], ['LUNCH BAG APPLE DESIGN']], 150),
#  ([['LUNCH BAG PINK POLKADOT'], ['LUNCH BAG BLACK SKULL']], 176),
#  ([['LUNCH BAG PINK POLKADOT'], ['LUNCH BAG CARS BLUE']], 167),
#  ([['LUNCH BAG PINK POLKADOT'], ['LUNCH BAG PINK POLKADOT']], 190),
#  ([['LUNCH BAG PINK POLKADOT'], ['LUNCH BAG RED RETROSPOT']], 186),
#  ([['LUNCH BAG PINK POLKADOT'], ['LUNCH BAG SPACEBOY DESIGN']], 157),
#  ([['LUNCH BAG PINK POLKADOT'], ['LUNCH BAG SUKI DESIGN']], 165),
#  ([['LUNCH BAG RED RETROSPOT'], ['JUMBO BAG RED RETROSPOT']], 188),
#  ([['LUNCH BAG RED RETROSPOT'], ['LUNCH BAG ALPHABET DESIGN']], 159),
#  ([['LUNCH BAG RED RETROSPOT'], ['LUNCH BAG APPLE DESIGN']], 180),
#  ([['LUNCH BAG RED RETROSPOT'], ['LUNCH BAG BLACK SKULL']], 201),
#  ([['LUNCH BAG RED RETROSPOT'], ['LUNCH BAG CARS BLUE']], 192),
#  ([['LUNCH BAG RED RETROSPOT'], ['LUNCH BAG PINK POLKADOT']], 192),
#  ([['LUNCH BAG RED RETROSPOT'], ['LUNCH BAG RED RETROSPOT']], 266),
#  ([['LUNCH BAG RED RETROSPOT'], ['LUNCH BAG SPACEBOY DESIGN']], 199),
#  ([['LUNCH BAG RED RETROSPOT'], ['LUNCH BAG SUKI DESIGN']], 194),
#  ([['LUNCH BAG RED RETROSPOT'], ['LUNCH BAG VINTAGE DOILY']], 154),
#  ([['LUNCH BAG RED RETROSPOT'], ['LUNCH BAG WOODLAND']], 170),
#  ([['LUNCH BAG SPACEBOY DESIGN'], ['LUNCH BAG ALPHABET DESIGN']], 154),
#  ([['LUNCH BAG SPACEBOY DESIGN'], ['LUNCH BAG APPLE DESIGN']], 152),
#  ([['LUNCH BAG SPACEBOY DESIGN'], ['LUNCH BAG BLACK SKULL']], 170),
#  ([['LUNCH BAG SPACEBOY DESIGN'], ['LUNCH BAG CARS BLUE']], 164),
#  ([['LUNCH BAG SPACEBOY DESIGN'], ['LUNCH BAG PINK POLKADOT']], 159),
#  ([['LUNCH BAG SPACEBOY DESIGN'], ['LUNCH BAG RED RETROSPOT']], 188),
#  ([['LUNCH BAG SPACEBOY DESIGN'], ['LUNCH BAG SPACEBOY DESIGN']], 189),
#  ([['LUNCH BAG SPACEBOY DESIGN'], ['LUNCH BAG SUKI DESIGN']], 181),
#  ([['LUNCH BAG SPACEBOY DESIGN'], ['LUNCH BAG WOODLAND']], 157),
#  ([['LUNCH BAG SUKI DESIGN'], ['LUNCH BAG ALPHABET DESIGN']], 154),
#  ([['LUNCH BAG SUKI DESIGN'], ['LUNCH BAG APPLE DESIGN']], 156),
#  ([['LUNCH BAG SUKI DESIGN'], ['LUNCH BAG BLACK SKULL']], 181),
#  ([['LUNCH BAG SUKI DESIGN'], ['LUNCH BAG CARS BLUE']], 173),
#  ([['LUNCH BAG SUKI DESIGN'], ['LUNCH BAG PINK POLKADOT']], 162),
#  ([['LUNCH BAG SUKI DESIGN'], ['LUNCH BAG RED RETROSPOT']], 190),
#  ([['LUNCH BAG SUKI DESIGN'], ['LUNCH BAG SPACEBOY DESIGN']], 168),
#  ([['LUNCH BAG SUKI DESIGN'], ['LUNCH BAG SUKI DESIGN']], 217),
#  ([['LUNCH BAG WOODLAND'], ['LUNCH BAG RED RETROSPOT']], 168),
#  ([['LUNCH BAG WOODLAND'], ['LUNCH BAG SPACEBOY DESIGN']], 155),
#  ([['LUNCH BAG WOODLAND'], ['LUNCH BAG WOODLAND']], 180),
#  ([['NATURAL SLATE HEART CHALKBOARD'], ['NATURAL SLATE HEART CHALKBOARD']],
#   175),
#  ([['PACK OF RETROSPOT CAKE CASES'], ['PACK OF RETROSPOT CAKE CASES']], 171),
#  ([['PAPER CHAIN KIT CHRISTMAS'], ['PAPER CHAIN KIT CHRISTMAS']], 161),
#  ([['PARTY BUNTING'], ['PARTY BUNTING']], 273),
#  ([['PARTY BUNTING'], ['SPOTTY BUNTING']], 179),
#  ([['PARTY BUNTING'], ['WHITE HANGING HEART TLIGHT HOLDER']], 165),
#  ([['RABBIT NIGHT LIGHT'], ['RABBIT NIGHT LIGHT']], 183),
#  ([['REGENCY CAKESTAND TIER'], ['PARTY BUNTING']], 168),
#  ([['REGENCY CAKESTAND TIER'], ['REGENCY CAKESTAND TIER']], 298),
#  ([['REGENCY CAKESTAND TIER'], ['ROSES REGENCY TEACUP AND SAUCER']], 150),
#  ([['REGENCY CAKESTAND TIER'], ['SET OF REGENCY CAKE TINS']], 190),
#  ([['REGENCY CAKESTAND TIER'], ['WHITE HANGING HEART TLIGHT HOLDER']], 167),
#  ([['REX CASHCARRY JUMBO SHOPPER'], ['REX CASHCARRY JUMBO SHOPPER']], 153),
#  ([['SET OF CAKE TINS PANTRY DESIGN'], ['SET OF CAKE TINS PANTRY DESIGN']],
#   217),
#  ([['SET OF PANTRY JELLY MOULDS'], ['SET OF PANTRY JELLY MOULDS']], 178),
#  ([['SPOTTY BUNTING'], ['PARTY BUNTING']], 170),
#  ([['SPOTTY BUNTING'], ['SPOTTY BUNTING']], 206),
#  ([['WHITE HANGING HEART TLIGHT HOLDER'], ['ASSORTED COLOUR BIRD ORNAMENT']],
#   153),
#  ([['WHITE HANGING HEART TLIGHT HOLDER'], ['HEART OF WICKER LARGE']], 151),
#  ([['WHITE HANGING HEART TLIGHT HOLDER'], ['PARTY BUNTING']], 157),
#  ([['WHITE HANGING HEART TLIGHT HOLDER'], ['REGENCY CAKESTAND TIER']], 150),
#  ([['WHITE HANGING HEART TLIGHT HOLDER'],
#    ['WHITE HANGING HEART TLIGHT HOLDER']],
#   368),
#  ([['WOODEN FRAME ANTIQUE WHITE'], ['WOODEN FRAME ANTIQUE WHITE']], 154),
#  ([['WOODEN PICTURE FRAME WHITE FINISH'], ['WOODEN FRAME ANTIQUE WHITE']],
#   157),
#  ([['WOODEN PICTURE FRAME WHITE FINISH'],
#    ['WOODEN PICTURE FRAME WHITE FINISH']],
#   165),
#  ([['JUMBO BAG RED RETROSPOT'],
#    ['JUMBO BAG RED RETROSPOT'],
#    ['JUMBO BAG RED RETROSPOT']],
#   176),
#  ([['LUNCH BAG RED RETROSPOT'],
#    ['LUNCH BAG RED RETROSPOT'],
#    ['LUNCH BAG RED RETROSPOT']],
#   151),
#  ([['WHITE HANGING HEART TLIGHT HOLDER'],
#    ['WHITE HANGING HEART TLIGHT HOLDER'],
#    ['WHITE HANGING HEART TLIGHT HOLDER']],
#   196)]

# %%
result = aprioriall(baskets_sequence, min_sup=150, verbose=False)
filter_maximal(result)
result
# Out:
# [([['ABC TREASURE BOOK BOX']], 157),
#  ([['ALARM CLOCK BAKELIKE CHOCOLATE']], 163),
#  ([['ALARM CLOCK BAKELIKE ORANGE']], 166),
#  ([['ANTIQUE SILVER TEA GLASS ENGRAVED']], 162),
#  ([['ANTIQUE SILVER TLIGHT GLASS']], 346),
#  ([['AREA PATROLLED METAL SIGN']], 172),
#  ([['ASSORTED COLOUR MINI CASES']], 223),
#  ([['ASSORTED COLOURS SILK FAN']], 187),
#  ([['BAG SWIRLY MARBLES']], 313),
#  ([['BATH BUILDING BLOCK WORD']], 155),
#  ([['BATHROOM METAL SIGN']], 218),
#  ([['BEWARE OF THE CAT METAL SIGN']], 168),
#  ([['BINGO SET']], 196),
#  ([['BISCUIT TIN CHRISTMAS']], 230),
#  ([['BISCUIT TIN VINTAGE CHRISTMAS']], 199),
#  ([['BLACKBLUE POLKADOT UMBRELLA']], 169),
#  ([['BLUE DINER WALL CLOCK']], 176),
#  ([['BLUE POLKADOT WRAP']], 166),
#  ([['BLUE SPOT CERAMIC DRAWER KNOB']], 154),
#  ([['BLUE STRIPE CERAMIC DRAWER KNOB']], 162),
#  ([['BOX OF COCKTAIL PARASOLS']], 193),
#  ([['BOX OF MINI CRACKERS']], 300),
#  ([['BOX OF MINI VINTAGE CRACKERS']], 270),
#  ([['BOX OF VINTAGE ALPHABET BLOCKS']], 154),
#  ([['BREAD BIN DINER STYLE IVORY']], 202),
#  ([['BUNDLE OF ALPHABET EXERCISE BOOKS']], 224),
#  ([['BUNDLE OF RETRO NOTE BOOKS']], 178),
#  ([['CAKE CASES DOLLY GIRL DESIGN']], 223),
#  ([['CAKE CASES VINTAGE CHRISTMAS']], 310),
#  ([['CARD BILLBOARD FONT']], 211),
#  ([['CARD CIRCUS PARADE']], 159),
#  ([['CERAMIC STRAWBERRY CAKE MONEY BANK']], 170),
#  ([['CHARLOTTE BAG APPLES DESIGN']], 199),
#  ([['CHARLOTTE BAG DOLLY GIRL DESIGN']], 164),
#  ([['CHARLOTTE BAG PINK POLKADOT']], 208),
#  ([['CHARLOTTE BAG SUKI DESIGN']], 239),
#  ([['CHARLOTTE BAG VINTAGE ALPHABET']], 192),
#  ([['CHICK GREY HOT WATER BOTTLE']], 162),
#  ([['CHILDRENS APRON APPLES DESIGN']], 194),
#  ([['CHILDRENS APRON DOLLY GIRL']], 177),
#  ([['CHILDRENS APRON SPACEBOY DESIGN']], 282),
#  ([['CHILDRENS CUTLERY POLKADOT BLUE']], 150),
#  ([['CHILDRENS CUTLERY POLKADOT PINK']], 208),
#  ([['CHILDRENS CUTLERY RETROSPOT RED']], 157),
#  ([['CHILLI LIGHTS']], 197),
#  ([['CHOCOLATE BOX RIBBONS']], 154),
#  ([['CHOCOLATE THIS WAY METAL SIGN']], 208),
#  ([['CHRISTMAS CRAFT TREE TOP ANGEL']], 235),
#  ([['CHRISTMAS GLASS BALL LIGHTS']], 152),
#  ([['CHRISTMAS LIGHTS REINDEER']], 170),
#  ([['CHRISTMAS STAR WISH LIST CHALKBOARD']], 195),
#  ([['CIRCUS PARADE LUNCH BOX']], 160),
#  ([['CLASSIC GLASS COOKIE JAR']], 189),
#  ([['CLASSIC METAL BIRDCAGE PLANT HOLDER']], 167),
#  ([['CLEAR DRAWER KNOB ACRYLIC EDWARDIAN']], 164),
#  ([['CLOTHES PEGS RETROSPOT PACK']], 334),
#  ([['COFFEE MUG APPLES DESIGN']], 153),
#  ([['COLOUR GLASS TLIGHT HOLDER HANGING']], 310),
#  ([['COLOUR SPACEBOY PEN']], 161),
#  ([['COOK WITH WINE METAL SIGN']], 273),
#  ([['CREAM HEART CARD HOLDER']], 264),
#  ([['CREAM SWEETHEART MINI CHEST']], 284),
#  ([['DECORATIVE WICKER HEART LARGE']], 168),
#  ([['DECORATIVE WICKER HEART MEDIUM']], 158),
#  ([['DOILIES VINTAGE CHRISTMAS']], 151),
#  ([['DOORMAT ENGLISH ROSE']], 216),
#  ([['DOORMAT FANCY FONT HOME SWEET HOME']], 191),
#  ([['DOORMAT HEARTS']], 273),
#  ([['DOORMAT HOME SWEET HOME BLUE']], 192),
#  ([['DOORMAT KEEP CALM AND COME IN']], 376),
#  ([['DOORMAT NEW ENGLAND']], 303),
#  ([['DOORMAT RED RETROSPOT']], 306),
#  ([['DOORMAT SPOTTY HOME SWEET HOME']], 236),
#  ([['DOORMAT UNION FLAG']], 290),
#  ([['DOORMAT WELCOME PUPPIES']], 155),
#  ([['DOORMAT WELCOME TO OUR HOME']], 226),
#  ([['DOORSTOP RETROSPOT HEART']], 163),
#  ([['DOUGHNUT LIP GLOSS']], 215),
#  ([['EDWARDIAN PARASOL NATURAL']], 176),
#  ([['ENAMEL BREAD BIN CREAM']], 180),
#  ([['ENAMEL FLOWER JUG CREAM']], 303),
#  ([['ENAMEL MEASURING JUG CREAM']], 218),
#  ([['ENGLISH ROSE HOT WATER BOTTLE']], 168),
#  ([['FAMILY ALBUM WHITE PICTURE FRAME']], 160),
#  ([['FAMILY PHOTO FRAME CORNICE']], 165),
#  ([['FANCY FONT BIRTHDAY CARD']], 160),
#  ([['FANCY FONTS BIRTHDAY WRAP']], 177),
#  ([['FAWN BLUE HOT WATER BOTTLE']], 207),
#  ([['FELTCRAFT BUTTERFLY HEARTS']], 267),
#  ([['FELTCRAFT CHRISTMAS FAIRY']], 201),
#  ([['FELTCRAFT CUSHION BUTTERFLY']], 174),
#  ([['FELTCRAFT CUSHION OWL']], 217),
#  ([['FELTCRAFT CUSHION RABBIT']], 174),
#  ([['FELTCRAFT DOLL EMILY']], 153),
#  ([['FELTCRAFT DOLL MOLLY']], 195),
#  ([['FELTCRAFT DOLL ROSIE']], 170),
#  ([['FELTCRAFT FLOWER FRIENDS']], 310),
#  ([['FELTCRAFT GIRL AMELIE KIT']], 187),
#  ([['FELTCRAFT PRINCESS OLIVIA DOLL']], 168),
#  ([['FRENCH ENAMEL CANDLEHOLDER']], 154),
#  ([['GIANT CHRISTMAS CRACKER']], 260),
#  ([['GIFT TAGS CHRISTMAS']], 234),
#  ([['GIFT TAGS VINTAGE CHRISTMAS']], 226),
#  ([['GIN TONIC DIET METAL SIGN']], 313),
#  ([['GINGERBREAD MAN COOKIE CUTTER']], 364),
#  ([['GINGHAM HEART DECORATION']], 251),
#  ([['GIRAFFE WOODEN RULER']], 185),
#  ([['GLASS APOTHECARY BOTTLE PERFUME']], 151),
#  ([['GRAND CHOCOLATECANDLE']], 172),
#  ([['GREY HEART HOT WATER BOTTLE']], 293),
#  ([['GROW A FLYTRAP OR SUNFLOWER IN TIN']], 163),
#  ([['GUMBALL COAT RACK']], 246),
#  ([['HAND OVER THE CHOCOLATE SIGN']], 259),
#  ([['HAND WARMER RED RETROSPOT']], 224),
#  ([['HAND WARMER UNION JACK']], 259),
#  ([['HANGING HEART JAR TLIGHT HOLDER']], 295),
#  ([['HANGING HEART ZINC TLIGHT HOLDER']], 260),
#  ([['HANGING JAM JAR TLIGHT HOLDER']], 191),
#  ([['HANGING METAL HEART LANTERN']], 183),
#  ([['HAPPY STENCIL CRAFT']], 156),
#  ([['HEART IVORY TRELLIS LARGE']], 178),
#  ([['HEARTS HANGING DECORATION RUSTIC']], 167),
#  ([['HOME SWEET HOME CUSHION COVER']], 165),
#  ([['HOME SWEET HOME METAL SIGN']], 159),
#  ([['HOME SWEET HOME MUG']], 161),
#  ([['HOMEMADE JAM SCENTED CANDLES']], 382),
#  ([['HOOK PHOTO SHELF ANTIQUE WHITE']], 167),
#  ([['HOT BATHS METAL SIGN']], 198),
#  ([['ICE CREAM PEN LIP GLOSS']], 158),
#  ([['ICE CREAM SUNDAE LIP GLOSS']], 202),
#  ([['IM ON HOLIDAY METAL SIGN']], 201),
#  ([['IVORY DINER WALL CLOCK']], 232),
#  ([['IVORY WICKER HEART LARGE']], 207),
#  ([['IVORY WICKER HEART MEDIUM']], 179),
#  ([['JAM JAR WITH PINK LID']], 161),
#  ([['JAZZ HEARTS PURSE NOTEBOOK']], 158),
#  ([['JINGLE BELL HEART ANTIQUE SILVER']], 162),
#  ([['JINGLE BELL HEART DECORATION']], 223),
#  ([['JUMBO BAG DOILEY PATTERNS']], 299),
#  ([['JUMBO BAG DOLLY GIRL DESIGN']], 164),
#  ([['JUMBO BAG OWLS']], 190),
#  ([['JUMBO BAG PAISLEY PARK']], 230),
#  ([['JUMBO BAG SCANDINAVIAN BLUE PAISLEY']], 232),
#  ([['JUMBO BAG SPACEBOY DESIGN']], 242),
#  ([['JUMBO BAG WOODLAND ANIMALS']], 242),
#  ([['JUMBO STORAGE BAG SKULLS']], 208),
#  ([['KEY FOB SHED']], 157),
#  ([['KNITTED UNION FLAG HOT WATER BOTTLE']], 168),
#  ([['LADIES GENTLEMEN METAL SIGN']], 181),
#  ([['LANTERN CREAM GAZEBO']], 176),
#  ([['LARGE CERAMIC TOP STORAGE JAR']], 166),
#  ([['LONDON BUS COFFEE MUG']], 175),
#  ([['LOVEBIRD HANGING DECORATION WHITE']], 174),
#  ([['LUNCH BAG DOILEY PATTERN']], 290),
#  ([['LUNCH BAG PAISLEY PARK']], 233),
#  ([['LUNCH BOX I LOVE LONDON']], 195),
#  ([['LUNCH BOX WITH CUTLERY RETROSPOT']], 174),
#  ([['MAGIC DRAWING SLATE SPACEBOY']], 157),
#  ([['MAGNETS PACK OF SWALLOWS']], 157),
#  ([['MEMO BOARD COTTAGE DESIGN']], 173),
#  ([['MEMO BOARD RETROSPOT DESIGN']], 223),
#  ([['METAL HOOK HANGER FRENCH CHATEAU']], 196),
#  ([['METAL SIGN TAKE IT OR LEAVE IT']], 219),
#  ([['MINI PAINT SET VINTAGE']], 196),
#  ([['MINT KITCHEN SCALES']], 181),
#  ([['MULTI COLOUR SILVER TLIGHT HOLDER']], 198),
#  ([['NATURAL SLATE CHALKBOARD LARGE']], 207),
#  ([['NATURAL SLATE RECTANGLE CHALKBOARD']], 204),
#  ([['NO SINGING METAL SIGN']], 200),
#  ([['OPEN CLOSED METAL SIGN']], 263),
#  ([['PACK OF BIRDY GIFT TAGS']], 212),
#  ([['PACK OF HEARTS DESIGN TISSUES']], 246),
#  ([['PACK OF LONDON TISSUES']], 174),
#  ([['PACK OF MUSHROOM CAKE CASES']], 172),
#  ([['PACK OF NAPKINS PANTRY DESIGN']], 352),
#  ([['PACK OF NAPKINS RED APPLES']], 207),
#  ([['PACK OF RED RETROSPOT TISSUES']], 180),
#  ([['PACK OF SKULL CAKE CASES']], 283),
#  ([['PACK OF SPACEBOY CAKE CASES']], 254),
#  ([['PACK OF SUKI TISSUES']], 167),
#  ([['PACK OF TRADITIONAL CRAYONS']], 219),
#  ([['PANTRY MAGNETIC SHOPPING LIST']], 258),
#  ([['PANTRY ROLLING PIN']], 151),
#  ([['PANTRY SCRUBBING BRUSH']], 198),
#  ([['PANTRY WASHING UP BRUSH']], 225),
#  ([['PAPER BUNTING RETROSPOT']], 316),
#  ([['PAPER CHAIN KIT EMPIRE']], 273),
#  ([['PAPER CHAIN KIT RETROSPOT']], 276),
#  ([['PARISIENNE JEWELLERY DRAWER']], 151),
#  ([['PARISIENNE KEY CABINET']], 150),
#  ([['PARTY METAL SIGN']], 231),
#  ([['PENCIL SMALL TUBE WOODLAND']], 177),
#  ([['PENCILS SMALL TUBE RED RETROSPOT']], 206),
#  ([['PENCILS SMALL TUBE SKULL']], 178),
#  ([['PENCILS TALL TUBE RED RETROSPOT']], 170),
#  ([['PENCILS TUBE RED RETROSPOT']], 153),
#  ([['PHOTO FRAME CORNICE']], 268),
#  ([['PICNIC BASKET WICKER LARGE']], 180),
#  ([['PICNIC BASKET WICKER SMALL']], 159),
#  ([['PICTURE DOMINOES']], 173),
#  ([['PIECE SPACEBOY COOKIE CUTTER SET']], 201),
#  ([['PIGGY BANK RETROSPOT']], 170),
#  ([['PINK BABY BUNTING']], 159),
#  ([['PINK FAIRY CAKE CHILDRENS APRON']], 240),
#  ([['PINK POLKADOT WRAP']], 158),
#  ([['PINK VINTAGE PAISLEY PICNIC BAG']], 192),
#  ([['PLACE SETTING WHITE HEART']], 162),
#  ([['PLASTERS IN TIN SKULLS']], 257),
#  ([['PLASTERS IN TIN STRONGMAN']], 274),
#  ([['PLASTERS IN TIN VINTAGE PAISLEY']], 288),
#  ([['PLAYING CARDS JUBILEE UNION JACK']], 164),
#  ([['PLAYING CARDS KEEP CALM CARRY ON']], 284),
#  ([['PLEASE ONE PERSON METAL SIGN']], 337),
#  ([['POLYESTER FILLER PAD']], 188),
#  ([['POPCORN HOLDER']], 295),
#  ([['POTTERING IN THE SHED METAL SIGN']], 218),
#  ([['QUEENS GUARD COFFEE MUG']], 160),
#  ([['RECIPE BOX BLUE SKETCHBOOK DESIGN']], 151),
#  ([['RECIPE BOX RETROSPOT']], 208),
#  ([['RECYCLING BAG RETROSPOT']], 175),
#  ([['RED DINER WALL CLOCK']], 204),
#  ([['RED RETROSPOT BOWL']], 178),
#  ([['RED RETROSPOT CAKE STAND']], 237),
#  ([['RED RETROSPOT CHARLOTTE BAG']], 327),
#  ([['RED RETROSPOT CUP']], 155),
#  ([['RED RETROSPOT MINI CASES']], 222),
#  ([['RED RETROSPOT OVEN GLOVE']], 167),
#  ([['RED RETROSPOT PEG BAG']], 195),
#  ([['RED RETROSPOT PICNIC BAG']], 220),
#  ([['RED RETROSPOT ROUND CAKE TINS']], 156),
#  ([['RED RETROSPOT SHOPPER BAG']], 229),
#  ([['RED RETROSPOT SMALL MILK JUG']], 203),
#  ([['RED RETROSPOT UMBRELLA']], 198),
#  ([['RED RETROSPOT WRAP']], 231),
#  ([['RED SPOT CERAMIC DRAWER KNOB']], 153),
#  ([['RED STRIPE CERAMIC DRAWER KNOB']], 164),
#  ([['RED TOADSTOOL LED NIGHT LIGHT']], 257),
#  ([['RED WOOLLY HOTTIE WHITE HEART']], 167),
#  ([['REGENCY TEA PLATE PINK']], 160),
#  ([['RETROSPOT CHILDRENS APRON']], 187),
#  ([['RETROSPOT HEART HOT WATER BOTTLE']], 318),
#  ([['RETROSPOT LARGE MILK JUG']], 195),
#  ([['RETROSPOT PARTY BAG STICKER SET']], 159),
#  ([['REVOLVER WOODEN RULER']], 216),
#  ([['RIBBON REEL HEARTS DESIGN']], 179),
#  ([['RIBBON REEL STRIPES DESIGN']], 225),
#  ([['RIBBONS RUSTIC CHARM']], 389),
#  ([['ROBOT BIRTHDAY CARD']], 169),
#  ([['ROLL WRAP CHRISTMAS']], 241),
#  ([['ROLL WRAP RED CHRISTMAS']], 151),
#  ([['ROLL WRAP VINTAGE CHRISTMAS']], 213),
#  ([['ROLL WRAP VINTAGE SPOT']], 204),
#  ([['ROMANTIC PINKS RIBBONS']], 153),
#  ([['ROTATING SILVER ANGELS TLIGHT HLDR']], 175),
#  ([['ROUND CAKE TIN VINTAGE RED']], 182),
#  ([['ROUND SNACK BOXES SET OF FRUITS']], 211),
#  ([['ROUND SNACK BOXES SET OF WOODLAND']], 264),
#  ([['SCANDINAVIAN PAISLEY PICNIC BAG']], 216),
#  ([['SCANDINAVIAN REDS RIBBONS']], 221),
#  ([['SCOTTIE DOG HOT WATER BOTTLE']], 358),
#  ([['SET BABUSHKA NESTING BOXES']], 161),
#  ([['SET BLUE POLKADOT PARTY CANDLES']], 172),
#  ([['SET COLOUR PENCILS DOLLY GIRL']], 192),
#  ([['SET COLOUR PENCILS LOVE LONDON']], 157),
#  ([['SET COLOUR PENCILS SPACEBOY']], 258),
#  ([['SET COLOURING PENCILS DOILY']], 174),
#  ([['SET KIDS COLOUR CHALK STICKS']], 181),
#  ([['SET NAPKINS FAIRY CAKES DESIGN']], 186),
#  ([['SET OF CAKE TINS SKETCHBOOK']], 175),
#  ([['SET OF DOILIES PANTRY DESIGN']], 172),
#  ([['SET OF HANGING OWLS OLLIE BEAK']], 169),
#  ([['SET OF HERB TINS SKETCHBOOK']], 164),
#  ([['SET OF I LOVE LONDON CAKE CASES']], 177),
#  ([['SET OF KIDS COOKIE CUTTERS']], 272),
#  ([['SET OF KNICK KNACK TINS DOILY']], 230),
#  ([['SET OF LED DOLLY LIGHTS']], 271),
#  ([['SET OF NOTEBOOKS IN PARCEL']], 226),
#  ([['SET OF PAISLEY FLOWER DOILIES']], 172),
#  ([['SET OF PANTRY DESIGN CAKE CASES']], 366),
#  ([['SET OF PINK HEART PAPER DOILIES']], 201),
#  ([['SET OF RETROSPOT PAPER DOILIES']], 230),
#  ([['SET OF RIBBONS VINTAGE CHRISTMAS']], 275),
#  ([['SET OF SOLDIER SKITTLES']], 230),
#  ([['SET OF TEA TOWELS APPLE AND PEARS']], 157),
#  ([['SET OF TEATIME PAPER DOILIES']], 193),
#  ([['SET OF VINTAGE CHRISTMAS NAPKINS']], 322),
#  ([['SET OF VINTAGE LEAF CAKE CASES']], 209),
#  ([['SET OF WOODEN HEART DECORATIONS']], 267),
#  ([['SET OF WOODEN SLEIGH DECORATIONS']], 177),
#  ([['SET OF WOODEN STOCKING DECORATION']], 200),
#  ([['SET OF WOODEN TREE DECORATIONS']], 179),
#  ([['SET PANTRY DESIGN TEA TOWELS']], 239),
#  ([['SET PAPER TABLE LANTERN HEARTS']], 205),
#  ([['SET PAPER TABLE LANTERN STARS']], 160),
#  ([['SET PAPER VINTAGE CHICK PAPER EGG']], 179),
#  ([['SET PINK POLKADOT PARTY CANDLES']], 202),
#  ([['SET RED GINGHAM ROSE STORAGE BOX']], 171),
#  ([['SET RED POLKADOT PARTY CANDLES']], 228),
#  ([['SET RED RETROSPOT LID GLASS BOWLS']], 340),
#  ([['SET RED RETROSPOT PAPER NAPKINS']], 404),
#  ([['SET RED SPOTTY PAPER CUPS']], 162),
#  ([['SET RED SPOTTY PAPER PLATES']], 173),
#  ([['SET SCHOOL MILK BOTTLES IN CRATE']], 195),
#  ([['SET TEA TOWELS I LOVE LONDON']], 176),
#  ([['SILVER BELLS TABLE DECORATION']], 180),
#  ([['SILVER STARS TABLE DECORATION']], 175),
#  ([['SINGLE ANTIQUE ROSE HOOK IVORY']], 169),
#  ([['SINGLE HEART ZINC TLIGHT HOLDER']], 218),
#  ([['SKULL LUNCH BOX WITH CUTLERY']], 161),
#  ([['SMALL DOLLY MIX DESIGN ORANGE BOWL']], 189),
#  ([['SMALL GLASS HEART TRINKET POT']], 207),
#  ([['SMALL MARSHMALLOWS PINK BOWL']], 164),
#  ([['SMALL POPCORN HOLDER']], 198),
#  ([['SOLDIERS EGG CUP']], 163),
#  ([['SPACEBOY BIRTHDAY CARD']], 226),
#  ([['SPACEBOY MINI BACKPACK']], 157),
#  ([['STRAWBERRY CERAMIC TRINKET BOX']], 268),
#  ([['STRAWBERRY CHARLOTTE BAG']], 226),
#  ([['STRAWBERRY LUNCH BOX WITH CUTLERY']], 227),
#  ([['STRIPEY MICE FELTCRAFT']], 262),
#  ([['SWALLOWS GREETING CARD']], 167),
#  ([['SWEETHEART CAKESTAND TIER']], 232),
#  ([['SWEETHEART CERAMIC TRINKET BOX']], 192),
#  ([['SWEETHEART FAIRY CAKE CASES']], 303),
#  ([['SWEETHEART RECIPE BOOK STAND']], 160),
#  ([['TEA PARTY BIRTHDAY CARD']], 176),
#  ([['TEA TIME PARTY BUNTING']], 186),
#  ([['TLIGHT GLASS FLUTED ANTIQUE']], 162),
#  ([['TOILET METAL SIGN']], 162),
#  ([['TRADITIONAL BISCUIT CUTTERS SET']], 155),
#  ([['TRADITIONAL CHRISTMAS RIBBONS']], 181),
#  ([['TRADITIONAL KNITTING NANCY']], 355),
#  ([['TRADITIONAL MODELLING CLAY']], 213),
#  ([['TRADITIONAL NAUGHTS CROSSES']], 195),
#  ([['TRADITIONAL PICK UP STICKS GAME']], 203),
#  ([['TRADITIONAL SPINNING TOPS']], 247),
#  ([['TRADITIONAL WOODEN CATCH CUP GAME']], 211),
#  ([['TRADITIONAL WOODEN SKIPPING ROPE']], 247),
#  ([['TRADTIONAL ALPHABET STAMP SET']], 152),
#  ([['TRAVEL CARD WALLET KEEP CALM']], 216),
#  ([['TRAVEL CARD WALLET VINTAGE TICKET']], 155),
#  ([['TRAVEL SEWING KIT']], 235),
#  ([['TREASURE ISLAND BOOK BOX']], 173),
#  ([['TREASURE TIN GYMKHANA DESIGN']], 183),
#  ([['VICTORIAN GLASS HANGING TLIGHT']], 390),
#  ([['VINTAGE CHRISTMAS BUNTING']], 253),
#  ([['VINTAGE CHRISTMAS GIFT SACK']], 168),
#  ([['VINTAGE CHRISTMAS STOCKING']], 245),
#  ([['VINTAGE CREAM DOG FOOD CONTAINER']], 169),
#  ([['VINTAGE DOILY JUMBO BAG RED']], 186),
#  ([['VINTAGE DOILY TRAVEL SEWING KIT']], 282),
#  ([['VINTAGE DONKEY TAIL GAME']], 181),
#  ([['VINTAGE LEAF MAGNETIC NOTEPAD']], 159),
#  ([['VINTAGE PAISLEY STATIONERY SET']], 153),
#  ([['VINTAGE SNAKES LADDERS']], 193),
#  ([['VINTAGE UNION JACK BUNTING']], 256),
#  ([['WASHROOM METAL SIGN']], 176),
#  ([['WATERING CAN BLUE ELEPHANT']], 158),
#  ([['WATERING CAN PINK BUNNY']], 153),
#  ([['WHITE SKULL HOT WATER BOTTLE']], 205),
#  ([['WHITE SPOT RED CERAMIC DRAWER KNOB']], 152),
#  ([['WHITE WICKER STAR']], 210),
#  ([['WHITE WOOD GARDEN PLANT LADDER']], 266),
#  ([['WICKER STAR']], 193),
#  ([['WOOD BLACK BOARD ANT WHITE FINISH']], 273),
#  ([['WOOD DRAWER CABINET WHITE FINISH']], 225),
#  ([['WOOD S CABINET ANT WHITE FINISH']], 168),
#  ([['WOODEN BOX OF DOMINOES']], 311),
#  ([['WOODEN CROQUET GARDEN SET']], 172),
#  ([['WOODEN ROUNDERS GARDEN SET']], 214),
#  ([['WOODEN SCHOOL COLOURING SET']], 272),
#  ([['WOODEN UNION JACK BUNTING']], 209),
#  ([['WOODLAND CHARLOTTE BAG']], 232),
#  ([['WORLD WAR GLIDERS ASSTD DESIGNS']], 294),
#  ([['WRAP ALPHABET DESIGN']], 176),
#  ([['WRAP ENGLISH ROSE']], 186),
#  ([['YOURE CONFUSING ME METAL SIGN']], 179),
#  ([['ZINC FOLKART SLEIGH BELLS']], 268),
#  ([['ZINC HERB GARDEN CONTAINER']], 154),
#  ([['ZINC METAL HEART DECORATION']], 288),
#  ([['ZINC TLIGHT HOLDER STARS SMALL']], 179),
#  ([['ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE PINK']], 168),
#  ([['ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE RED']], 231),
#  ([['ALARM CLOCK BAKELIKE IVORY', 'ALARM CLOCK BAKELIKE RED']], 168),
#  ([['ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE RED']], 198),
#  ([['ASSORTED COLOUR BIRD ORNAMENT', 'PAINTED METAL PEARS ASSORTED']], 172),
#  ([['ASSORTED COLOUR BIRD ORNAMENT', 'REGENCY CAKESTAND TIER']], 158),
#  ([['ASSORTED COLOUR BIRD ORNAMENT', 'WHITE HANGING HEART TLIGHT HOLDER']],
#   165),
#  ([['BAKING SET PIECE RETROSPOT', 'BAKING SET SPACEBOY DESIGN']], 230),
#  ([['BAKING SET PIECE RETROSPOT', 'RETROSPOT TEA SET CERAMIC PC']], 167),
#  ([['BLUE HAPPY BIRTHDAY BUNTING', 'PINK HAPPY BIRTHDAY BUNTING']], 182),
#  ([['BLUE HARMONICA IN BOX', 'RED HARMONICA IN BOX']], 162),
#  ([['CANDLEHOLDER PINK HANGING HEART', 'WHITE HANGING HEART TLIGHT HOLDER']],
#   164),
#  ([['CHILDRENS CUTLERY DOLLY GIRL', 'CHILDRENS CUTLERY SPACEBOY']], 157),
#  ([['CHOCOLATE HOT WATER BOTTLE', 'HOT WATER BOTTLE I AM SO POORLY']], 163),
#  ([['CHOCOLATE HOT WATER BOTTLE', 'HOT WATER BOTTLE KEEP CALM']], 161),
#  ([['CHOCOLATE HOT WATER BOTTLE', 'HOT WATER BOTTLE TEA AND SYMPATHY']], 158),
#  ([['CHRISTMAS CRAFT LITTLE FRIENDS', 'CHRISTMAS CRAFT WHITE FAIRY']], 153),
#  ([['DOLLY GIRL LUNCH BOX', 'SPACEBOY LUNCH BOX']], 210),
#  ([['FELTCRAFT PRINCESS CHARLOTTE DOLL', 'FELTCRAFT PRINCESS LOLA DOLL']],
#   154),
#  ([['GARDENERS KNEELING PAD CUP OF TEA', 'GARDENERS KNEELING PAD KEEP CALM']],
#   254),
#  ([['GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER']],
#   281),
#  ([['GREEN REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND TIER']], 235),
#  ([['GREEN REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER']],
#   303),
#  ([['HAND WARMER BIRD DESIGN', 'HAND WARMER OWL DESIGN']], 175),
#  ([['HAND WARMER BIRD DESIGN', 'HAND WARMER SCOTTY DOG DESIGN']], 151),
#  ([['HAND WARMER OWL DESIGN', 'HAND WARMER RED LOVE HEART']], 151),
#  ([['HAND WARMER OWL DESIGN', 'HAND WARMER SCOTTY DOG DESIGN']], 171),
#  ([['HEART OF WICKER LARGE', 'HEART OF WICKER SMALL']], 244),
#  ([['HEART OF WICKER LARGE', 'LARGE WHITE HEART OF WICKER']], 153),
#  ([['HEART OF WICKER LARGE', 'WHITE HANGING HEART TLIGHT HOLDER']], 179),
#  ([['HEART OF WICKER SMALL', 'SMALL WHITE HEART OF WICKER']], 151),
#  ([['HEART OF WICKER SMALL', 'WHITE HANGING HEART TLIGHT HOLDER']], 166),
#  ([['HOME BUILDING BLOCK WORD', 'LOVE BUILDING BLOCK WORD']], 174),
#  ([['HOT WATER BOTTLE KEEP CALM', 'HOT WATER BOTTLE TEA AND SYMPATHY']], 160),
#  ([['HOT WATER BOTTLE KEEP CALM', 'LOVE HOT WATER BOTTLE']], 171),
#  ([['IVORY KITCHEN SCALES', 'RED KITCHEN SCALES']], 166),
#  ([['JAM MAKING SET PRINTED', 'JAM MAKING SET WITH JARS']], 197),
#  ([['JAM MAKING SET WITH JARS', 'SET OF CAKE TINS PANTRY DESIGN']], 177),
#  ([['JUMBO BAG ALPHABET', 'JUMBO BAG APPLES']], 158),
#  ([['JUMBO BAG ALPHABET', 'JUMBO BAG RED RETROSPOT']], 177),
#  ([['JUMBO BAG ALPHABET', 'JUMBO BAG VINTAGE LEAF']], 159),
#  ([['JUMBO BAG ALPHABET', 'LUNCH BAG ALPHABET DESIGN']], 162),
#  ([['JUMBO BAG APPLES', 'JUMBO BAG PEARS']], 177),
#  ([['JUMBO BAG APPLES', 'JUMBO BAG RED RETROSPOT']], 191),
#  ([['JUMBO BAG APPLES', 'JUMBO BAG VINTAGE LEAF']], 158),
#  ([['JUMBO BAG APPLES', 'LUNCH BAG APPLE DESIGN']], 175),
#  ([['JUMBO BAG BAROQUE BLACK WHITE', 'JUMBO BAG RED RETROSPOT']], 187),
#  ([['JUMBO BAG CHRISTMAS', 'JUMBO BAG VINTAGE CHRISTMAS']], 177),
#  ([['JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT']], 243),
#  ([['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT']], 176),
#  ([['JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY']], 201),
#  ([['JUMBO BAG RED RETROSPOT', 'JUMBO BAG VINTAGE DOILY']], 183),
#  ([['JUMBO BAG RED RETROSPOT', 'JUMBO BAG VINTAGE LEAF']], 180),
#  ([['JUMBO BAG RED RETROSPOT', 'JUMBO SHOPPER VINTAGE RED PAISLEY']], 184),
#  ([['JUMBO BAG RED RETROSPOT', 'JUMBO STORAGE BAG SUKI']], 189),
#  ([['JUMBO BAG RED RETROSPOT', 'LUNCH BAG PINK POLKADOT']], 159),
#  ([['JUMBO BAG RED RETROSPOT', 'LUNCH BAG RED RETROSPOT']], 210),
#  ([['JUMBO BAG VINTAGE DOILY', 'JUMBO BAG VINTAGE LEAF']], 154),
#  ([['JUMBO BAG VINTAGE DOILY', 'LUNCH BAG VINTAGE DOILY']], 151),
#  ([['LARGE WHITE HEART OF WICKER', 'SMALL WHITE HEART OF WICKER']], 205),
#  ([['LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG APPLE DESIGN']], 191),
#  ([['LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG BLACK SKULL']], 158),
#  ([['LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG CARS BLUE']], 160),
#  ([['LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG RED RETROSPOT']], 160),
#  ([['LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG SPACEBOY DESIGN']], 158),
#  ([['LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG SUKI DESIGN']], 160),
#  ([['LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG VINTAGE LEAF DESIGN']], 153),
#  ([['LUNCH BAG APPLE DESIGN', 'LUNCH BAG BLACK SKULL']], 172),
#  ([['LUNCH BAG APPLE DESIGN', 'LUNCH BAG CARS BLUE']], 171),
#  ([['LUNCH BAG APPLE DESIGN', 'LUNCH BAG PINK POLKADOT']], 164),
#  ([['LUNCH BAG APPLE DESIGN', 'LUNCH BAG RED RETROSPOT']], 195),
#  ([['LUNCH BAG APPLE DESIGN', 'LUNCH BAG SPACEBOY DESIGN']], 172),
#  ([['LUNCH BAG APPLE DESIGN', 'LUNCH BAG SUKI DESIGN']], 183),
#  ([['LUNCH BAG APPLE DESIGN', 'LUNCH BAG VINTAGE LEAF DESIGN']], 174),
#  ([['LUNCH BAG APPLE DESIGN', 'LUNCH BAG WOODLAND']], 159),
#  ([['LUNCH BAG BLACK SKULL', 'LUNCH BAG CARS BLUE']], 202),
#  ([['LUNCH BAG BLACK SKULL', 'LUNCH BAG PINK POLKADOT']], 228),
#  ([['LUNCH BAG BLACK SKULL', 'LUNCH BAG RED RETROSPOT']], 242),
#  ([['LUNCH BAG BLACK SKULL', 'LUNCH BAG SPACEBOY DESIGN']], 207),
#  ([['LUNCH BAG BLACK SKULL', 'LUNCH BAG SUKI DESIGN']], 216),
#  ([['LUNCH BAG BLACK SKULL', 'LUNCH BAG WOODLAND']], 174),
#  ([['LUNCH BAG CARS BLUE', 'LUNCH BAG PINK POLKADOT']], 236),
#  ([['LUNCH BAG CARS BLUE', 'LUNCH BAG RED RETROSPOT']], 244),
#  ([['LUNCH BAG CARS BLUE', 'LUNCH BAG SPACEBOY DESIGN']], 217),
#  ([['LUNCH BAG CARS BLUE', 'LUNCH BAG SUKI DESIGN']], 238),
#  ([['LUNCH BAG CARS BLUE', 'LUNCH BAG WOODLAND']], 191),
#  ([['LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG RED RETROSPOT']], 161),
#  ([['LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG SPACEBOY DESIGN']], 187),
#  ([['LUNCH BAG PINK POLKADOT', 'LUNCH BAG RED RETROSPOT']], 248),
#  ([['LUNCH BAG PINK POLKADOT', 'LUNCH BAG SPACEBOY DESIGN']], 193),
#  ([['LUNCH BAG PINK POLKADOT', 'LUNCH BAG SUKI DESIGN']], 199),
#  ([['LUNCH BAG PINK POLKADOT', 'LUNCH BAG WOODLAND']], 163),
#  ([['LUNCH BAG RED RETROSPOT', 'LUNCH BAG SPACEBOY DESIGN']], 234),
#  ([['LUNCH BAG RED RETROSPOT', 'LUNCH BAG SUKI DESIGN']], 239),
#  ([['LUNCH BAG RED RETROSPOT', 'LUNCH BAG WOODLAND']], 208),
#  ([['LUNCH BAG SPACEBOY DESIGN', 'LUNCH BAG SUKI DESIGN']], 228),
#  ([['LUNCH BAG SPACEBOY DESIGN', 'LUNCH BAG WOODLAND']], 216),
#  ([['LUNCH BAG SUKI DESIGN', 'LUNCH BAG WOODLAND']], 175),
#  ([['NATURAL SLATE HEART CHALKBOARD', 'WHITE HANGING HEART TLIGHT HOLDER']],
#   171),
#  ([['PACK OF DINOSAUR CAKE CASES', 'PACK OF RETROSPOT CAKE CASES']], 159),
#  ([['PACK OF PINK PAISLEY CAKE CASES', 'PACK OF RETROSPOT CAKE CASES']], 224),
#  ([['PACK OF PINK PAISLEY CAKE CASES', 'TEATIME FAIRY CAKE CASES']], 171),
#  ([['PACK OF RETROSPOT CAKE CASES', 'TEATIME FAIRY CAKE CASES']], 212),
#  ([['PAPER CHAIN KIT CHRISTMAS', 'PAPER CHAIN KIT VINTAGE CHRISTMAS']], 278),
#  ([['PARTY BUNTING', 'REGENCY CAKESTAND TIER']], 168),
#  ([['PARTY BUNTING', 'SPOTTY BUNTING']], 243),
#  ([['PARTY BUNTING', 'WHITE HANGING HEART TLIGHT HOLDER']], 173),
#  ([['PINK BLUE FELT CRAFT TRINKET BOX', 'PINK CREAM FELT CRAFT TRINKET BOX']],
#   150),
#  ([['PINK REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND TIER']], 208),
#  ([['PINK REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER']],
#   255),
#  ([['PLASTERS IN TIN CIRCUS PARADE', 'PLASTERS IN TIN WOODLAND ANIMALS']],
#   152),
#  ([['PLASTERS IN TIN SPACEBOY', 'PLASTERS IN TIN WOODLAND ANIMALS']], 172),
#  ([['POPPYS PLAYHOUSE BEDROOM', 'POPPYS PLAYHOUSE KITCHEN']], 154),
#  ([['RECIPE BOX PANTRY YELLOW DESIGN', 'SET OF CAKE TINS PANTRY DESIGN']],
#   187),
#  ([['RED HANGING HEART TLIGHT HOLDER', 'WHITE HANGING HEART TLIGHT HOLDER']],
#   253),
#  ([['REGENCY CAKESTAND TIER', 'REGENCY TEAPOT ROSES']], 155),
#  ([['REGENCY CAKESTAND TIER', 'ROSES REGENCY TEACUP AND SAUCER']], 254),
#  ([['REGENCY CAKESTAND TIER', 'SET OF CAKE TINS PANTRY DESIGN']], 154),
#  ([['REGENCY CAKESTAND TIER', 'SET OF REGENCY CAKE TINS']], 193),
#  ([['REGENCY CAKESTAND TIER', 'WHITE HANGING HEART TLIGHT HOLDER']], 155),
#  ([['REGENCY MILK JUG PINK', 'REGENCY SUGAR BOWL GREEN']], 162),
#  ([['REGENCY MILK JUG PINK', 'REGENCY TEAPOT ROSES']], 154),
#  ([['REGENCY SUGAR BOWL GREEN', 'REGENCY TEAPOT ROSES']], 154),
#  ([['REGENCY TEA PLATE GREEN', 'REGENCY TEA PLATE ROSES']], 165),
#  ([['SET OF BUTTERFLY COOKIE CUTTERS', 'SET OF HEART COOKIE CUTTERS']], 177),
#  ([['SET OF CAKE TINS PANTRY DESIGN', 'SET OF SPICE TINS PANTRY DESIGN']],
#   212),
#  ([['SET OF CAKE TINS PANTRY DESIGN', 'SET OF TEA COFFEE SUGAR TINS PANTRY']],
#   165),
#  ([['SET OF FAIRY CAKE BAKING CASES', 'SET OF MINI LOAF BAKING CASES']], 180),
#  ([['SET OF FAIRY CAKE BAKING CASES', 'SET OF SNACK LOAF BAKING CASES']], 158),
#  ([['SET OF FAIRY CAKE BAKING CASES', 'SET OF TEA TIME BAKING CASES']], 168),
#  ([['SET OF MINI LOAF BAKING CASES', 'SET OF SNACK LOAF BAKING CASES']], 150),
#  ([['SET OF MINI LOAF BAKING CASES', 'SET OF TEA TIME BAKING CASES']], 150),
#  ([['VINTAGE HEADS AND TAILS CARD GAME', 'VINTAGE SNAP CARDS']], 169),
#  ([['WHITE HANGING HEART TLIGHT HOLDER', 'WOODEN PICTURE FRAME WHITE FINISH']],
#   150),
#  ([['WOODEN FRAME ANTIQUE WHITE', 'WOODEN PICTURE FRAME WHITE FINISH']], 234),
#  ([['WOODEN HEART CHRISTMAS SCANDINAVIAN',
#     'WOODEN STAR CHRISTMAS SCANDINAVIAN']],
#   240),
#  ([['WOODEN HEART CHRISTMAS SCANDINAVIAN',
#     'WOODEN TREE CHRISTMAS SCANDINAVIAN']],
#   158),
#  ([['WOODEN STAR CHRISTMAS SCANDINAVIAN',
#     'WOODEN TREE CHRISTMAS SCANDINAVIAN']],
#   179),
#  ([['ALARM CLOCK BAKELIKE GREEN'], ['ALARM CLOCK BAKELIKE RED']], 159),
#  ([['ALARM CLOCK BAKELIKE RED'], ['ALARM CLOCK BAKELIKE GREEN']], 155),
#  ([['ALARM CLOCK BAKELIKE RED'], ['ALARM CLOCK BAKELIKE RED']], 182),
#  ([['ASSORTED COLOUR BIRD ORNAMENT'], ['ASSORTED COLOUR BIRD ORNAMENT']], 275),
#  ([['HEART OF WICKER SMALL'], ['HEART OF WICKER SMALL']], 176),
#  ([['HEART OF WICKER SMALL'], ['WHITE HANGING HEART TLIGHT HOLDER']], 157),
#  ([['JUMBO BAG ALPHABET'], ['JUMBO BAG ALPHABET']], 157),
#  ([['JUMBO BAG ALPHABET'], ['JUMBO BAG RED RETROSPOT']], 158),
#  ([['JUMBO BAG APPLES'], ['JUMBO BAG RED RETROSPOT']], 163),
#  ([['JUMBO BAG PINK POLKADOT'], ['JUMBO BAG PINK POLKADOT']], 156),
#  ([['JUMBO BAG PINK POLKADOT'], ['JUMBO BAG RED RETROSPOT']], 183),
#  ([['JUMBO BAG RED RETROSPOT'], ['JUMBO BAG ALPHABET']], 166),
#  ([['JUMBO BAG RED RETROSPOT'], ['JUMBO BAG APPLES']], 183),
#  ([['JUMBO BAG RED RETROSPOT'], ['JUMBO BAG CHRISTMAS']], 163),
#  ([['JUMBO BAG RED RETROSPOT'], ['JUMBO BAG PINK POLKADOT']], 176),
#  ([['JUMBO BAG RED RETROSPOT'], ['JUMBO BAG VINTAGE DOILY']], 178),
#  ([['JUMBO BAG RED RETROSPOT'], ['JUMBO BAG VINTAGE LEAF']], 166),
#  ([['JUMBO BAG RED RETROSPOT'], ['LUNCH BAG BLACK SKULL']], 156),
#  ([['JUMBO BAG RED RETROSPOT'], ['LUNCH BAG PINK POLKADOT']], 154),
#  ([['JUMBO BAG RED RETROSPOT'], ['LUNCH BAG RED RETROSPOT']], 188),
#  ([['JUMBO BAG VINTAGE LEAF'], ['JUMBO BAG VINTAGE LEAF']], 151),
#  ([['JUMBO SHOPPER VINTAGE RED PAISLEY'], ['JUMBO BAG RED RETROSPOT']], 153),
#  ([['JUMBO STORAGE BAG SUKI'], ['JUMBO BAG RED RETROSPOT']], 151),
#  ([['LUNCH BAG ALPHABET DESIGN'], ['LUNCH BAG RED RETROSPOT']], 156),
#  ([['LUNCH BAG APPLE DESIGN'], ['LUNCH BAG APPLE DESIGN']], 186),
#  ([['LUNCH BAG APPLE DESIGN'], ['LUNCH BAG RED RETROSPOT']], 171),
#  ([['LUNCH BAG BLACK SKULL'], ['LUNCH BAG ALPHABET DESIGN']], 152),
#  ([['LUNCH BAG BLACK SKULL'], ['LUNCH BAG APPLE DESIGN']], 151),
#  ([['LUNCH BAG BLACK SKULL'], ['LUNCH BAG BLACK SKULL']], 221),
#  ([['LUNCH BAG BLACK SKULL'], ['LUNCH BAG CARS BLUE']], 169),
#  ([['LUNCH BAG BLACK SKULL'], ['LUNCH BAG PINK POLKADOT']], 171),
#  ([['LUNCH BAG BLACK SKULL'], ['LUNCH BAG RED RETROSPOT']], 204),
#  ([['LUNCH BAG BLACK SKULL'], ['LUNCH BAG SPACEBOY DESIGN']], 163),
#  ([['LUNCH BAG BLACK SKULL'], ['LUNCH BAG SUKI DESIGN']], 181),
#  ([['LUNCH BAG BLACK SKULL'], ['LUNCH BAG WOODLAND']], 150),
#  ([['LUNCH BAG CARS BLUE'], ['JUMBO BAG RED RETROSPOT']], 155),
#  ([['LUNCH BAG CARS BLUE'], ['LUNCH BAG ALPHABET DESIGN']], 154),
#  ([['LUNCH BAG CARS BLUE'], ['LUNCH BAG APPLE DESIGN']], 156),
#  ([['LUNCH BAG CARS BLUE'], ['LUNCH BAG BLACK SKULL']], 178),
#  ([['LUNCH BAG CARS BLUE'], ['LUNCH BAG CARS BLUE']], 197),
#  ([['LUNCH BAG CARS BLUE'], ['LUNCH BAG PINK POLKADOT']], 176),
#  ([['LUNCH BAG CARS BLUE'], ['LUNCH BAG RED RETROSPOT']], 188),
#  ([['LUNCH BAG CARS BLUE'], ['LUNCH BAG SPACEBOY DESIGN']], 161),
#  ([['LUNCH BAG CARS BLUE'], ['LUNCH BAG SUKI DESIGN']], 178),
#  ([['LUNCH BAG PINK POLKADOT'], ['JUMBO BAG RED RETROSPOT']], 159),
#  ([['LUNCH BAG PINK POLKADOT'], ['LUNCH BAG ALPHABET DESIGN']], 150),
#  ([['LUNCH BAG PINK POLKADOT'], ['LUNCH BAG APPLE DESIGN']], 150),
#  ([['LUNCH BAG PINK POLKADOT'], ['LUNCH BAG BLACK SKULL']], 176),
#  ([['LUNCH BAG PINK POLKADOT'], ['LUNCH BAG CARS BLUE']], 167),
#  ([['LUNCH BAG PINK POLKADOT'], ['LUNCH BAG PINK POLKADOT']], 190),
#  ([['LUNCH BAG PINK POLKADOT'], ['LUNCH BAG RED RETROSPOT']], 186),
#  ([['LUNCH BAG PINK POLKADOT'], ['LUNCH BAG SPACEBOY DESIGN']], 157),
#  ([['LUNCH BAG PINK POLKADOT'], ['LUNCH BAG SUKI DESIGN']], 165),
#  ([['LUNCH BAG RED RETROSPOT'], ['JUMBO BAG RED RETROSPOT']], 188),
#  ([['LUNCH BAG RED RETROSPOT'], ['LUNCH BAG ALPHABET DESIGN']], 159),
#  ([['LUNCH BAG RED RETROSPOT'], ['LUNCH BAG APPLE DESIGN']], 180),
#  ([['LUNCH BAG RED RETROSPOT'], ['LUNCH BAG BLACK SKULL']], 201),
#  ([['LUNCH BAG RED RETROSPOT'], ['LUNCH BAG CARS BLUE']], 192),
#  ([['LUNCH BAG RED RETROSPOT'], ['LUNCH BAG PINK POLKADOT']], 192),
#  ([['LUNCH BAG RED RETROSPOT'], ['LUNCH BAG SPACEBOY DESIGN']], 199),
#  ([['LUNCH BAG RED RETROSPOT'], ['LUNCH BAG SUKI DESIGN']], 194),
#  ([['LUNCH BAG RED RETROSPOT'], ['LUNCH BAG VINTAGE DOILY']], 154),
#  ([['LUNCH BAG RED RETROSPOT'], ['LUNCH BAG WOODLAND']], 170),
#  ([['LUNCH BAG SPACEBOY DESIGN'], ['LUNCH BAG ALPHABET DESIGN']], 154),
#  ([['LUNCH BAG SPACEBOY DESIGN'], ['LUNCH BAG APPLE DESIGN']], 152),
#  ([['LUNCH BAG SPACEBOY DESIGN'], ['LUNCH BAG BLACK SKULL']], 170),
#  ([['LUNCH BAG SPACEBOY DESIGN'], ['LUNCH BAG CARS BLUE']], 164),
#  ([['LUNCH BAG SPACEBOY DESIGN'], ['LUNCH BAG PINK POLKADOT']], 159),
#  ([['LUNCH BAG SPACEBOY DESIGN'], ['LUNCH BAG RED RETROSPOT']], 188),
#  ([['LUNCH BAG SPACEBOY DESIGN'], ['LUNCH BAG SPACEBOY DESIGN']], 189),
#  ([['LUNCH BAG SPACEBOY DESIGN'], ['LUNCH BAG SUKI DESIGN']], 181),
#  ([['LUNCH BAG SPACEBOY DESIGN'], ['LUNCH BAG WOODLAND']], 157),
#  ([['LUNCH BAG SUKI DESIGN'], ['LUNCH BAG ALPHABET DESIGN']], 154),
#  ([['LUNCH BAG SUKI DESIGN'], ['LUNCH BAG APPLE DESIGN']], 156),
#  ([['LUNCH BAG SUKI DESIGN'], ['LUNCH BAG BLACK SKULL']], 181),
#  ([['LUNCH BAG SUKI DESIGN'], ['LUNCH BAG CARS BLUE']], 173),
#  ([['LUNCH BAG SUKI DESIGN'], ['LUNCH BAG PINK POLKADOT']], 162),
#  ([['LUNCH BAG SUKI DESIGN'], ['LUNCH BAG RED RETROSPOT']], 190),
#  ([['LUNCH BAG SUKI DESIGN'], ['LUNCH BAG SPACEBOY DESIGN']], 168),
#  ([['LUNCH BAG SUKI DESIGN'], ['LUNCH BAG SUKI DESIGN']], 217),
#  ([['LUNCH BAG WOODLAND'], ['LUNCH BAG RED RETROSPOT']], 168),
#  ([['LUNCH BAG WOODLAND'], ['LUNCH BAG SPACEBOY DESIGN']], 155),
#  ([['LUNCH BAG WOODLAND'], ['LUNCH BAG WOODLAND']], 180),
#  ([['NATURAL SLATE HEART CHALKBOARD'], ['NATURAL SLATE HEART CHALKBOARD']],
#   175),
#  ([['PACK OF RETROSPOT CAKE CASES'], ['PACK OF RETROSPOT CAKE CASES']], 171),
#  ([['PAPER CHAIN KIT CHRISTMAS'], ['PAPER CHAIN KIT CHRISTMAS']], 161),
#  ([['PARTY BUNTING'], ['PARTY BUNTING']], 273),
#  ([['PARTY BUNTING'], ['SPOTTY BUNTING']], 179),
#  ([['PARTY BUNTING'], ['WHITE HANGING HEART TLIGHT HOLDER']], 165),
#  ([['RABBIT NIGHT LIGHT'], ['RABBIT NIGHT LIGHT']], 183),
#  ([['REGENCY CAKESTAND TIER'], ['PARTY BUNTING']], 168),
#  ([['REGENCY CAKESTAND TIER'], ['REGENCY CAKESTAND TIER']], 298),
#  ([['REGENCY CAKESTAND TIER'], ['ROSES REGENCY TEACUP AND SAUCER']], 150),
#  ([['REGENCY CAKESTAND TIER'], ['SET OF REGENCY CAKE TINS']], 190),
#  ([['REGENCY CAKESTAND TIER'], ['WHITE HANGING HEART TLIGHT HOLDER']], 167),
#  ([['REX CASHCARRY JUMBO SHOPPER'], ['REX CASHCARRY JUMBO SHOPPER']], 153),
#  ([['SET OF CAKE TINS PANTRY DESIGN'], ['SET OF CAKE TINS PANTRY DESIGN']],
#   217),
#  ([['SET OF PANTRY JELLY MOULDS'], ['SET OF PANTRY JELLY MOULDS']], 178),
#  ([['SPOTTY BUNTING'], ['PARTY BUNTING']], 170),
#  ([['SPOTTY BUNTING'], ['SPOTTY BUNTING']], 206),
#  ([['WHITE HANGING HEART TLIGHT HOLDER'], ['ASSORTED COLOUR BIRD ORNAMENT']],
#   153),
#  ([['WHITE HANGING HEART TLIGHT HOLDER'], ['HEART OF WICKER LARGE']], 151),
#  ([['WHITE HANGING HEART TLIGHT HOLDER'], ['PARTY BUNTING']], 157),
#  ([['WHITE HANGING HEART TLIGHT HOLDER'], ['REGENCY CAKESTAND TIER']], 150),
#  ([['WOODEN FRAME ANTIQUE WHITE'], ['WOODEN FRAME ANTIQUE WHITE']], 154),
#  ([['WOODEN PICTURE FRAME WHITE FINISH'], ['WOODEN FRAME ANTIQUE WHITE']],
#   157),
#  ([['WOODEN PICTURE FRAME WHITE FINISH'],
#    ['WOODEN PICTURE FRAME WHITE FINISH']],
#   165),
#  ([['JUMBO BAG RED RETROSPOT'],
#    ['JUMBO BAG RED RETROSPOT'],
#    ['JUMBO BAG RED RETROSPOT']],
#   176),
#  ([['LUNCH BAG RED RETROSPOT'],
#    ['LUNCH BAG RED RETROSPOT'],
#    ['LUNCH BAG RED RETROSPOT']],
#   151),
#  ([['WHITE HANGING HEART TLIGHT HOLDER'],
#    ['WHITE HANGING HEART TLIGHT HOLDER'],
#    ['WHITE HANGING HEART TLIGHT HOLDER']],
#   196)]
